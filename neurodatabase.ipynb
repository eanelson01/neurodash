# %%
import numpy as np
import pandas as pd
import json
import os

# %%
# Neurons
f = open('Data/neuromorpho_neuron.json', 'r')
neurons = json.loads(f.read())
f.close()

# Morphology Data
f = open('Data/neuromorpho_morphology.json', 'r')
morpho = json.loads(f.read())
f.close()

# Models
f = open('Data/modeldb_models.json', 'r')
models = json.loads(f.read())
f.close()

# Celltypes
f = open('Data/modeldb_celltype.json', 'r')
celltypes = json.loads(f.read())
f.close()

# Regions
f = open('Data/modeldb_regions.json', 'r')
regions = json.loads(f.read())
f.close()

# Papers
f = open('Data/modeldb_papers.json', 'r')
papers = json.loads(f.read())
f.close()

# NeuroElectro
electro = pd.read_csv('Data/neuro_electro.csv', sep = '\t')

# %% [markdown]
# # Database Tables (brainstorming)
# * neurons
#     * **neuron_id**
#     * doi
#     * pmid
#     * brain_region
#     * cell_type
#         * connects to publication on doi or pmid
# * neuron_cell_type
#     * **neuron_id**
#     * cell_type
# * neuron_exp_condition
#     * **neuron_id**
#     * experiment_condition
# * neuron_pmid
#     * **neuron_id**
#     * reference_pmid
# * neuron_doi
#     * **neuron_id**
#     * reference_doi
# * electro_pub
#     * **Index**
#     * Pmid
# * models
#     * **id** (name this model id)
#     * model_paper_id
#     * neurons.value.id
#     *
#         * Connects to modeldb_papers which can connect to publications (model_paper_id)
#         * Connects to celltype on neurons.values.id
# * publications
#     * **pmid**
#     * doi
# * regions
#     * **id** (name this region_id)
#     * name
#         * not sure how this is connecting so far
# * celltypes
#     * **id** (name this celltype_id)
#     * Connects to neuroelectro (id to Index)
#     * Can connect to neuron (region to url, going to be difficult)
# * electro
#     * **Index**
#     * Pmid
#     * NeuronName
#     * ArticleID
#         * Connects to publications on pmid
#         * connects to neurons on brain_region or neuronname or publication

# %% [markdown]
# # Neurons

# %%
neuron_df = pd.json_normalize(neurons)

# %%
neuron_df.head(3).T
# Out:
#                                                                                 0  \
# neuron_id                                                                       1
# neuron_name                                                              cnic_001
# archive                                                                Wearne_Hof
# note                            When originally released, this reconstruction ...
# age_scale                                                                    Year
# gender                                                                Male/Female
# age_classification                                                            old
# brain_region                                     [neocortex, prefrontal, layer 3]
# cell_type                           [Local projecting, pyramidal, principal cell]
# species                                                                    monkey
# strain                                                                     Rhesus
# scientific_name                                                    Macaca mulatta
# stain                                                              lucifer yellow
# experiment_condition                                                    [Control]
# protocol                                                                  in vivo
# slicing_direction                                                          custom
# reconstruction_software                                                 Neurozoom
# objective_type                                                       Not reported
# original_format                                                     Neurozoom.swc
# domain                                                   Dendrites, Soma, No Axon
# attributes                                                   Diameter, 3D, Angles
# magnification                                                                 100
# upload_date                                                            2006-08-01
# deposition_date                                                        2005-12-31
# shrinkage_reported                                                       Reported
# shrinkage_corrected                                                 Not Corrected
# reported_value                                                               None
# reported_xy                                                                  None
# reported_z                                                                   None
# corrected_value                                                              None
# corrected_xy                                                                 None
# corrected_z                                                                  None
# soma_surface                                                                834.0
# surface                                                                   8842.91
# volume                                                                    4725.89
# slicing_thickness                                                             400
# min_age                                                                      24.0
# max_age                                                                      25.0
# min_weight                                                                 4500.0
# max_weight                                                                10000.0
# png_url                         http://neuromorpho.org/images/imageFiles/Wearn...
# reference_pmid                                               [12204204, 12902394]
# reference_doi                   [10.1016/S0306-4522(02)00305-6, 10.1093/cercor...
# physical_Integrity                                             Dendrites Moderate
# _links.self.href                           http://neuromorpho.org/api/neuron/id/1
# _links.measurements.href              http://neuromorpho.org/api/morphometry/id/1
# _links.persistence_vector.href               http://neuromorpho.org/api/pvec/id/1
#
#                                                                                 1  \
# neuron_id                                                                      10
# neuron_name                                                              cnic_041
# archive                                                                Wearne_Hof
# note                            When originally released, this reconstruction ...
# age_scale                                                                    Year
# gender                                                                Male/Female
# age_classification                                                            old
# brain_region                                     [neocortex, prefrontal, layer 3]
# cell_type                           [Local projecting, pyramidal, principal cell]
# species                                                                    monkey
# strain                                                                     Rhesus
# scientific_name                                                    Macaca mulatta
# stain                                                              lucifer yellow
# experiment_condition                                                    [Control]
# protocol                                                                  in vivo
# slicing_direction                                                          custom
# reconstruction_software                                                 Neurozoom
# objective_type                                                       Not reported
# original_format                                                     Neurozoom.swc
# domain                                                   Dendrites, Soma, No Axon
# attributes                                                   Diameter, 3D, Angles
# magnification                                                                 100
# upload_date                                                            2006-08-01
# deposition_date                                                        2005-12-31
# shrinkage_reported                                                       Reported
# shrinkage_corrected                                                 Not Corrected
# reported_value                                                               None
# reported_xy                                                                  None
# reported_z                                                                   None
# corrected_value                                                              None
# corrected_xy                                                                 None
# corrected_z                                                                  None
# soma_surface                                                              817.784
# surface                                                                   6601.59
# volume                                                                    4330.41
# slicing_thickness                                                             400
# min_age                                                                      24.0
# max_age                                                                      25.0
# min_weight                                                                 4500.0
# max_weight                                                                10000.0
# png_url                         http://neuromorpho.org/images/imageFiles/Wearn...
# reference_pmid                                               [12902394, 12204204]
# reference_doi                   [10.1093/cercor/13.9.950, 10.1016/S0306-4522(0...
# physical_Integrity                                             Dendrites Moderate
# _links.self.href                          http://neuromorpho.org/api/neuron/id/10
# _links.measurements.href             http://neuromorpho.org/api/morphometry/id/10
# _links.persistence_vector.href              http://neuromorpho.org/api/pvec/id/10
#
#                                                                                 2
# neuron_id                                                                     100
# neuron_name                                                                  n419
# archive                                                                    Turner
# note                            When originally released, this reconstruction ...
# age_scale                                                                   Month
# gender                                                                Male/Female
# age_classification                                                          young
# brain_region                                                   [hippocampus, CA1]
# cell_type                                             [pyramidal, principal cell]
# species                                                                       rat
# strain                                                                Fischer 344
# scientific_name                                                 rattus norvegicus
# stain                                                                    biocytin
# experiment_condition                                                    [Control]
# protocol                                                                  in vivo
# slicing_direction                                                         coronal
# reconstruction_software                                               Neurolucida
# objective_type                                                                oil
# original_format                                                   Neurolucida.swc
# domain                                                   Dendrites, Soma, No Axon
# attributes                                                   Diameter, 3D, Angles
# magnification                                                                 100
# upload_date                                                            2006-08-01
# deposition_date                                                        2005-12-31
# shrinkage_reported                                                       Reported
# shrinkage_corrected                                                     Corrected
# reported_value                                                               None
# reported_xy                                                                  25.0
# reported_z                                                                   75.0
# corrected_value                                                              None
# corrected_xy                                                                133.0
# corrected_z                                                                 400.0
# soma_surface                                                              897.846
# surface                                                                   23909.3
# volume                                                                    4215.04
# slicing_thickness                                                              80
# min_age                                                                       2.0
# max_age                                                                       8.0
# min_weight                                                                  200.0
# max_weight                                                                  350.0
# png_url                         http://neuromorpho.org/images/imageFiles/Turne...
# reference_pmid                                                          [9492204]
# reference_doi                   [10.1002/(SICI)1096-9861(19980216)391:3<335::A...
# physical_Integrity                                             Dendrites Complete
# _links.self.href                         http://neuromorpho.org/api/neuron/id/100
# _links.measurements.href            http://neuromorpho.org/api/morphometry/id/100
# _links.persistence_vector.href             http://neuromorpho.org/api/pvec/id/100

# %% [markdown]
# ### Notes on normal forms
#
# There is some data that is not atomic so far, need to fix that. List of non-atomic data:
# * brain_region
# * cell_type
# * experiment_condition
# * reference_pmid
# * rederence_doi
#
# ### Questions to think about:
# * Cell type table for non-atomic
# * Can I just drop certain columns I don't expect to use?

# %% [markdown]
# ### Non-atomic data

# %% [markdown]
# #### Brain Regions
# The brain regions can just be different columns, named region, subregion, subsubregion

# %%
# got an error with NoneType, check if some have region as empty
sum(neuron_df['brain_region'].isnull())
# there are 2,512 with no brain region
# Out:
# 2512

# %%
# check which are null
idx = neuron_df['brain_region'].isnull()
neuron_df[idx]
# Out:
#         neuron_id        neuron_name   archive  \
# 46504      144732  cs36_roi4_stacked  Brennand
# 46505      144733  cs11_roi1_stacked  Brennand
# 46506      144734  cs17_roi1_stacked  Brennand
# 46507      144735  cs10_roi5_stacked  Brennand
# 46508      144736  cs30_roi3_stacked  Brennand
# ...           ...                ...       ...
# 235737      77489        298_Cyst2_3     Koshy
# 235739      77490          298_Cyst4     Koshy
# 235740      77491          298_Cyst6     Koshy
# 235741      77492          298_Cyst9     Koshy
# 235742      77493          822_Cyst2     Koshy
#
#                                                      note age_scale  \
# 46504   This reconstruction belongs to C2 cell line. A...       Day
# 46505   This reconstruction belongs to C2 cell line. A...       Day
# 46506   This reconstruction belongs to C2 cell line. A...       Day
# 46507   This reconstruction belongs to C2 cell line. A...       Day
# 46508   This reconstruction belongs to C2 cell line. A...       Day
# ...                                                   ...       ...
# 235737                                                        Month
# 235739                                                        Month
# 235740                                                        Month
# 235741                                                        Month
# 235742                                                        Month
#
#              gender age_classification brain_region  \
# 46504          Male              fetus         None
# 46505          Male              fetus         None
# 46506          Male              fetus         None
# 46507          Male              fetus         None
# 46508          Male              fetus         None
# ...             ...                ...          ...
# 235737  Male/Female              adult         None
# 235739  Male/Female              adult         None
# 235740  Male/Female              adult         None
# 235741  Male/Female              adult         None
# 235742  Male/Female              adult         None
#
#                                                 cell_type species  ...  \
# 46504   [principal cell, induced pluripotent stem cell...   human  ...
# 46505   [principal cell, induced pluripotent stem cell...   human  ...
# 46506   [principal cell, induced pluripotent stem cell...   human  ...
# 46507   [principal cell, induced pluripotent stem cell...   human  ...
# 46508   [principal cell, induced pluripotent stem cell...   human  ...
# ...                                                   ...     ...  ...
# 235737                                   [principal cell]   mouse  ...
# 235739                                   [principal cell]   mouse  ...
# 235740                                   [principal cell]   mouse  ...
# 235741                                   [principal cell]   mouse  ...
# 235742                                   [principal cell]   mouse  ...
#
#        max_age    min_weight    max_weight  \
# 46504     24.0  Not Reported  Not Reported
# 46505     24.0  Not Reported  Not Reported
# 46506     24.0  Not Reported  Not Reported
# 46507     24.0  Not Reported  Not Reported
# 46508     24.0  Not Reported  Not Reported
# ...        ...           ...           ...
# 235737     3.0  Not Reported  Not Reported
# 235739     3.0  Not Reported  Not Reported
# 235740     3.0  Not Reported  Not Reported
# 235741     3.0  Not Reported  Not Reported
# 235742     3.0  Not Reported  Not Reported
#
#                                                   png_url  \
# 46504   http://neuromorpho.org/images/imageFiles/Brenn...
# 46505   http://neuromorpho.org/images/imageFiles/Brenn...
# 46506   http://neuromorpho.org/images/imageFiles/Brenn...
# 46507   http://neuromorpho.org/images/imageFiles/Brenn...
# 46508   http://neuromorpho.org/images/imageFiles/Brenn...
# ...                                                   ...
# 235737  http://neuromorpho.org/images/imageFiles/Koshy...
# 235739  http://neuromorpho.org/images/imageFiles/Koshy...
# 235740  http://neuromorpho.org/images/imageFiles/Koshy...
# 235741  http://neuromorpho.org/images/imageFiles/Koshy...
# 235742  http://neuromorpho.org/images/imageFiles/Koshy...
#
#               reference_pmid                                  reference_doi  \
# 46504             [31548722]                    [10.1038/s41588-019-0497-5]
# 46505             [31548722]                    [10.1038/s41588-019-0497-5]
# 46506             [31548722]                    [10.1038/s41588-019-0497-5]
# 46507             [31548722]                    [10.1038/s41588-019-0497-5]
# 46508             [31548722]                    [10.1038/s41588-019-0497-5]
# ...                      ...                                            ...
# 235737  [26895155, 25549001]  [10.1371/journal.ppat.1005447, 10.3791/52237]
# 235739  [26895155, 25549001]  [10.1371/journal.ppat.1005447, 10.3791/52237]
# 235740  [26895155, 25549001]  [10.1371/journal.ppat.1005447, 10.3791/52237]
# 235741  [26895155, 25549001]  [10.1371/journal.ppat.1005447, 10.3791/52237]
# 235742  [26895155, 25549001]  [10.1371/journal.ppat.1005447, 10.3791/52237]
#
#         physical_Integrity                             _links.self.href  \
# 46504    Neurites Moderate  http://neuromorpho.org/api/neuron/id/144732
# 46505    Neurites Moderate  http://neuromorpho.org/api/neuron/id/144733
# 46506    Neurites Moderate  http://neuromorpho.org/api/neuron/id/144734
# 46507    Neurites Moderate  http://neuromorpho.org/api/neuron/id/144735
# 46508    Neurites Moderate  http://neuromorpho.org/api/neuron/id/144736
# ...                    ...                                          ...
# 235737  Dendrites Moderate   http://neuromorpho.org/api/neuron/id/77489
# 235739  Dendrites Moderate   http://neuromorpho.org/api/neuron/id/77490
# 235740  Dendrites Moderate   http://neuromorpho.org/api/neuron/id/77491
# 235741  Dendrites Moderate   http://neuromorpho.org/api/neuron/id/77492
# 235742  Dendrites Moderate   http://neuromorpho.org/api/neuron/id/77493
#
#                                 _links.measurements.href  \
# 46504   http://neuromorpho.org/api/morphometry/id/144732
# 46505   http://neuromorpho.org/api/morphometry/id/144733
# 46506   http://neuromorpho.org/api/morphometry/id/144734
# 46507   http://neuromorpho.org/api/morphometry/id/144735
# 46508   http://neuromorpho.org/api/morphometry/id/144736
# ...                                                  ...
# 235737   http://neuromorpho.org/api/morphometry/id/77489
# 235739   http://neuromorpho.org/api/morphometry/id/77490
# 235740   http://neuromorpho.org/api/morphometry/id/77491
# 235741   http://neuromorpho.org/api/morphometry/id/77492
# 235742   http://neuromorpho.org/api/morphometry/id/77493
#
#                    _links.persistence_vector.href
# 46504   http://neuromorpho.org/api/pvec/id/144732
# 46505   http://neuromorpho.org/api/pvec/id/144733
# 46506   http://neuromorpho.org/api/pvec/id/144734
# 46507   http://neuromorpho.org/api/pvec/id/144735
# 46508   http://neuromorpho.org/api/pvec/id/144736
# ...                                           ...
# 235737   http://neuromorpho.org/api/pvec/id/77489
# 235739   http://neuromorpho.org/api/pvec/id/77490
# 235740   http://neuromorpho.org/api/pvec/id/77491
# 235741   http://neuromorpho.org/api/pvec/id/77492
# 235742   http://neuromorpho.org/api/pvec/id/77493
#
# [2512 rows x 47 columns]

# %%
# I can just make the null values have None in each of the 3 rows
neuron_df['brain_region_len'] = [len(x) if x != None else None for x in neuron_df['brain_region']]
#set([len(x) if x != None else None for x in neuron_df['brain_region']])

# %%
# there is sometimes more than 3 rows
neuron_df['brain_region_len'].value_counts()
# Out:
# brain_region_len
# 2.0    90535
# 3.0    76320
# 1.0    42354
# 4.0    39674
# 5.0     7529
# 6.0      784
# 7.0      300
# 8.0       70
# Name: count, dtype: int64

# %% [markdown]
# **Looking at the website, they appear to keep the brain regions to 3 and just combine the rest of the regions in the brain region 3. I can combined it into a string. This at least allows for querying of the primary brain region. [An example neuron where there is more than 3 brain regions on the NeuroMorpho website](https://neuromorpho.org/neuron_info.jsp?neuron_name=TA-40x)**

# %%
# start by making 3 columns and putting an None list for each 
none_col = [None] * len(neuron_df)
# pbr = primary brain region
# sbr = seconary ...
# tbr = tertiary ...
pbr = pd.Series(none_col)
sbr = pd.Series(none_col)
tbr = pd.Series(none_col)

# %%
test = pd.Series(none_col)
test[0] = neuron_df['brain_region'][0][0]

# %%
for i in range(len(neuron_df)):
    region_list = neuron_df['brain_region'][i]
    if region_list != None:
        if len(region_list) == 1:
            pbr[i] = region_list[0]
        elif len(region_list) == 2:
            pbr[i] = region_list[0]
            sbr[i] = region_list[1]
        else:
            pbr[i] = region_list[0]
            sbr[i] = region_list[1]
            tbr[i] = ' '.join(region_list[2:])

# %%
neuron_df['primary_brain_region'] = pbr
neuron_df['secondary_brain_region'] = sbr
neuron_df['tertiary_brain_region'] = tbr

# %%
neuron_df.head(3).T
# Out:
#                                                                                 0  \
# neuron_id                                                                       1
# neuron_name                                                              cnic_001
# archive                                                                Wearne_Hof
# note                            When originally released, this reconstruction ...
# age_scale                                                                    Year
# gender                                                                Male/Female
# age_classification                                                            old
# brain_region                                     [neocortex, prefrontal, layer 3]
# cell_type                           [Local projecting, pyramidal, principal cell]
# species                                                                    monkey
# strain                                                                     Rhesus
# scientific_name                                                    Macaca mulatta
# stain                                                              lucifer yellow
# experiment_condition                                                    [Control]
# protocol                                                                  in vivo
# slicing_direction                                                          custom
# reconstruction_software                                                 Neurozoom
# objective_type                                                       Not reported
# original_format                                                     Neurozoom.swc
# domain                                                   Dendrites, Soma, No Axon
# attributes                                                   Diameter, 3D, Angles
# magnification                                                                 100
# upload_date                                                            2006-08-01
# deposition_date                                                        2005-12-31
# shrinkage_reported                                                       Reported
# shrinkage_corrected                                                 Not Corrected
# reported_value                                                               None
# reported_xy                                                                  None
# reported_z                                                                   None
# corrected_value                                                              None
# corrected_xy                                                                 None
# corrected_z                                                                  None
# soma_surface                                                                834.0
# surface                                                                   8842.91
# volume                                                                    4725.89
# slicing_thickness                                                             400
# min_age                                                                      24.0
# max_age                                                                      25.0
# min_weight                                                                 4500.0
# max_weight                                                                10000.0
# png_url                         http://neuromorpho.org/images/imageFiles/Wearn...
# reference_pmid                                               [12204204, 12902394]
# reference_doi                   [10.1016/S0306-4522(02)00305-6, 10.1093/cercor...
# physical_Integrity                                             Dendrites Moderate
# _links.self.href                           http://neuromorpho.org/api/neuron/id/1
# _links.measurements.href              http://neuromorpho.org/api/morphometry/id/1
# _links.persistence_vector.href               http://neuromorpho.org/api/pvec/id/1
# brain_region_len                                                              3.0
# primary_brain_region                                                    neocortex
# secondary_brain_region                                                 prefrontal
# tertiary_brain_region                                                     layer 3
#
#                                                                                 1  \
# neuron_id                                                                      10
# neuron_name                                                              cnic_041
# archive                                                                Wearne_Hof
# note                            When originally released, this reconstruction ...
# age_scale                                                                    Year
# gender                                                                Male/Female
# age_classification                                                            old
# brain_region                                     [neocortex, prefrontal, layer 3]
# cell_type                           [Local projecting, pyramidal, principal cell]
# species                                                                    monkey
# strain                                                                     Rhesus
# scientific_name                                                    Macaca mulatta
# stain                                                              lucifer yellow
# experiment_condition                                                    [Control]
# protocol                                                                  in vivo
# slicing_direction                                                          custom
# reconstruction_software                                                 Neurozoom
# objective_type                                                       Not reported
# original_format                                                     Neurozoom.swc
# domain                                                   Dendrites, Soma, No Axon
# attributes                                                   Diameter, 3D, Angles
# magnification                                                                 100
# upload_date                                                            2006-08-01
# deposition_date                                                        2005-12-31
# shrinkage_reported                                                       Reported
# shrinkage_corrected                                                 Not Corrected
# reported_value                                                               None
# reported_xy                                                                  None
# reported_z                                                                   None
# corrected_value                                                              None
# corrected_xy                                                                 None
# corrected_z                                                                  None
# soma_surface                                                              817.784
# surface                                                                   6601.59
# volume                                                                    4330.41
# slicing_thickness                                                             400
# min_age                                                                      24.0
# max_age                                                                      25.0
# min_weight                                                                 4500.0
# max_weight                                                                10000.0
# png_url                         http://neuromorpho.org/images/imageFiles/Wearn...
# reference_pmid                                               [12902394, 12204204]
# reference_doi                   [10.1093/cercor/13.9.950, 10.1016/S0306-4522(0...
# physical_Integrity                                             Dendrites Moderate
# _links.self.href                          http://neuromorpho.org/api/neuron/id/10
# _links.measurements.href             http://neuromorpho.org/api/morphometry/id/10
# _links.persistence_vector.href              http://neuromorpho.org/api/pvec/id/10
# brain_region_len                                                              3.0
# primary_brain_region                                                    neocortex
# secondary_brain_region                                                 prefrontal
# tertiary_brain_region                                                     layer 3
#
#                                                                                 2
# neuron_id                                                                     100
# neuron_name                                                                  n419
# archive                                                                    Turner
# note                            When originally released, this reconstruction ...
# age_scale                                                                   Month
# gender                                                                Male/Female
# age_classification                                                          young
# brain_region                                                   [hippocampus, CA1]
# cell_type                                             [pyramidal, principal cell]
# species                                                                       rat
# strain                                                                Fischer 344
# scientific_name                                                 rattus norvegicus
# stain                                                                    biocytin
# experiment_condition                                                    [Control]
# protocol                                                                  in vivo
# slicing_direction                                                         coronal
# reconstruction_software                                               Neurolucida
# objective_type                                                                oil
# original_format                                                   Neurolucida.swc
# domain                                                   Dendrites, Soma, No Axon
# attributes                                                   Diameter, 3D, Angles
# magnification                                                                 100
# upload_date                                                            2006-08-01
# deposition_date                                                        2005-12-31
# shrinkage_reported                                                       Reported
# shrinkage_corrected                                                     Corrected
# reported_value                                                               None
# reported_xy                                                                  25.0
# reported_z                                                                   75.0
# corrected_value                                                              None
# corrected_xy                                                                133.0
# corrected_z                                                                 400.0
# soma_surface                                                              897.846
# surface                                                                   23909.3
# volume                                                                    4215.04
# slicing_thickness                                                              80
# min_age                                                                       2.0
# max_age                                                                       8.0
# min_weight                                                                  200.0
# max_weight                                                                  350.0
# png_url                         http://neuromorpho.org/images/imageFiles/Turne...
# reference_pmid                                                          [9492204]
# reference_doi                   [10.1002/(SICI)1096-9861(19980216)391:3<335::A...
# physical_Integrity                                             Dendrites Complete
# _links.self.href                         http://neuromorpho.org/api/neuron/id/100
# _links.measurements.href            http://neuromorpho.org/api/morphometry/id/100
# _links.persistence_vector.href             http://neuromorpho.org/api/pvec/id/100
# brain_region_len                                                              2.0
# primary_brain_region                                                  hippocampus
# secondary_brain_region                                                        CA1
# tertiary_brain_region                                                        None

# %% [markdown]
# #### Cell Type
# Cell type table for non-atomic
# * opting to just make a seperate table

# %%
neuron_df['cell_type'].value_counts()
# Out:
# cell_type
# [Glia, microglia, Iba1-positive]                     59673
# [principal cell, pyramidal]                          34029
# [principal cell]                                     19146
# [pyramidal, principal cell]                          10978
# [Glia, astrocyte, GFAP-positive]                      5551
#                                                      ...
# [principal cell, LPT23a]                                 1
# [principal cell, LPT3b]                                  1
# [sensory, horizontal-motion-sensitive neuron, H2]        1
# [principal cell, LPT34b]                                 1
# [principal cell, output neuron, AV4f1, AV4f]             1
# Name: count, Length: 2786, dtype: int64

# %%
# a large number of elements in the cell type value, so make it a seperate table
set([len(x) if x != None else None for x in neuron_df['cell_type']])
# Out:
# {1, 10, 11, 15, 16, 2, 3, 4, 5, 6, 7, 8, 9, None}

# %%
# going to make these vlaues just their own rows, it will be a neuron_cell_type table that has id and cell type
neuron_cell_type = neuron_df[['neuron_id', 'cell_type']].explode('cell_type')
neuron_cell_type.head()
# Out:
#    neuron_id         cell_type
# 0          1  Local projecting
# 0          1         pyramidal
# 0          1    principal cell
# 1         10  Local projecting
# 1         10         pyramidal

# %% [markdown]
# #### Experiment Condition

# %%
# experiment condition can have 1, 2, or 3 values in the list of conditions
set([len(x) for x in neuron_df['experiment_condition']])
# Out:
# {1, 2, 3}

# %%
# 909 have greater than 1 experiment condition
len([x for x in neuron_df['experiment_condition'] if len(x) > 1])
# Out:
# 909

# %%
[x for x in neuron_df['experiment_condition'] if len(x) > 1][0]
# Out:
# ['Human APP with Indiana(V717F)',
#  'Swedish(K670N+M671L)',
#  'Arctic(E22G) mutations + C5a receptor 1 knockout']

# %%
# opting to do the same thing for experiment condition as I did for cell type
neuron_exp_condition = neuron_df[['neuron_id', 'experiment_condition']].explode('experiment_condition')

# %% [markdown]
# #### Domain

# %%
# could make a boolean value for dendrite/soma/axon/processes/neurites/
# do 0 for false and 1 for true
neuron_df['domain'].value_counts()
# Out:
# domain
# Dendrites, Soma, No Axon       77532
# Processes, Soma                60482
# No Dendrites, No Soma, Axon    29936
# Neurites, Soma                 24368
# Dendrites, Soma, Axon          20901
# Dendrites, No Soma, No Axon    19220
# Neurites, No Soma              15108
# Processes, No Soma             10576
# No Dendrites, Soma, Axon        1313
# Dendrites, No Soma, Axon         642
# Name: count, dtype: int64

# %%
# dendrite, soma, axon, processes, neurites
dendrite = pd.Series(none_col)
soma = pd.Series(none_col)
axon = pd.Series(none_col)
processes = pd.Series(none_col)
neurites = pd.Series(none_col)

# %%
for i in range(len(neuron_df['domain'])):
    domains = neuron_df['domain'][i].split(', ')
    if 'Dendrites' in domains:
        dendrite[i] = 1
    else:
        dendrite[i] = 0
    if 'Soma' in domains:
        soma[i] = 1
    else:
        soma[i] = 0
    if 'Axon' in domains:
        axon[i] = 1
    else:
        axon[i] = 0
    if 'Processes' in domains:
        processes[i] = 1
    else:
        processes[i] = 0
    if 'Neurites' in domains:
        neurites[i] = 1
    else:
        neurites[i] = 0

# %%
neuron_df['dendrites'] = dendrite
neuron_df['soma'] = soma
neuron_df['axon'] = axon
neuron_df['processes'] = processes
neuron_df['neurites'] = neurites

# %% [markdown]
# #### Attributes

# %%
# could also make boolean values for diameter/3d/2d/angles/
neuron_df['attributes'].value_counts()
# Out:
# attributes
# No Diameter, 3D, Angles    144045
# Diameter, 3D, Angles        65550
# No Diameter, 2D, Angles     42635
# Diameter, 2D, Angles         7550
# Diameter, 3D, No Angles       297
# Diameter, 2D, No Angles         1
# Name: count, dtype: int64

# %%
# same thing for attributes as domain
# Diameter, 3D, Angles
att_diameter = pd.Series(none_col)
att_angles = pd.Series(none_col)
att_3D = pd.Series(none_col)

# %%
for i in range(len(neuron_df['attributes'])):
    domains = neuron_df['attributes'][i].split(', ')
    if 'Diameter' in domains:
        att_diameter[i] = 1
    else:
        att_diameter[i] = 0
    if '3D' in domains:
        att_3D[i] = 1
    else:
        att_3D[i] = 0
    if 'Angles' in domains:
        att_angles[i] = 1
    else:
        att_angles[i] = 0

# %%
neuron_df['att_diameter'] = att_diameter
neuron_df['att_angles'] = att_angles
neuron_df['att_3D'] = att_3D

# %% [markdown]
# #### Reference pmid
# * How can I express doi/pmid as non-atomic:
#     * Publications table with the pmids and dois

# %%
neuron_df['reference_pmid']
# Out:
# 0         [12204204, 12902394]
# 1         [12902394, 12204204]
# 2                    [9492204]
# 3                   [15054049]
# 4                   [19910365]
#                   ...
# 260073              [30013046]
# 260074              [30013046]
# 260075              [30013046]
# 260076              [30013046]
# 260077              [30013046]
# Name: reference_pmid, Length: 260078, dtype: object

# %%
# most only have 1 pmid
pd.Series([len(x) for x in neuron_df['reference_pmid']]).value_counts()
# Out:
# 1    256530
# 2      2178
# 4      1073
# 3       297
# Name: count, dtype: int64

# %%
neuron_df['reference_doi']
# Out:
# 0         [10.1016/S0306-4522(02)00305-6, 10.1093/cercor...
# 1         [10.1093/cercor/13.9.950, 10.1016/S0306-4522(0...
# 2         [10.1002/(SICI)1096-9861(19980216)391:3<335::A...
# 3                                   [10.1093/cercor/bhh029]
# 4                                      [10.1093/nar/gkp952]
#                                 ...
# 260073                          [10.1038/s41592-018-0049-4]
# 260074                          [10.1038/s41592-018-0049-4]
# 260075                          [10.1038/s41592-018-0049-4]
# 260076                          [10.1038/s41592-018-0049-4]
# 260077                          [10.1038/s41592-018-0049-4]
# Name: reference_doi, Length: 260078, dtype: object

# %%
# some have 0 doi
pd.Series([len(x) if x != None else 0 for x in neuron_df['reference_doi']]).value_counts()
# Out:
# 1    256515
# 2      2178
# 4      1073
# 3       297
# 0        15
# Name: count, dtype: int64

# %%
# some don't have a doi but have a pmid
# not sure I can confirm that a gien doi matches to the pmid
# might be able to use an api to pull pmid using the doi
neuron_pmid = neuron_df[['neuron_id', 'reference_pmid']].explode('reference_pmid')
neuron_pmid
# Out:
#         neuron_id reference_pmid
# 0               1       12204204
# 0               1       12902394
# 1              10       12902394
# 1              10       12204204
# 2             100        9492204
# ...           ...            ...
# 260073      99995       30013046
# 260074      99996       30013046
# 260075      99997       30013046
# 260076      99998       30013046
# 260077      99999       30013046
#
# [266069 rows x 2 columns]

# %% [markdown]
# #### Reference doi

# %%
neuron_doi = neuron_df[['neuron_id', 'reference_doi']].explode('reference_doi')
neuron_doi
# Out:
#         neuron_id                                      reference_doi
# 0               1                      10.1016/S0306-4522(02)00305-6
# 0               1                            10.1093/cercor/13.9.950
# 1              10                            10.1093/cercor/13.9.950
# 1              10                      10.1016/S0306-4522(02)00305-6
# 2             100  10.1002/(SICI)1096-9861(19980216)391:3<335::AI...
# ...           ...                                                ...
# 260073      99995                          10.1038/s41592-018-0049-4
# 260074      99996                          10.1038/s41592-018-0049-4
# 260075      99997                          10.1038/s41592-018-0049-4
# 260076      99998                          10.1038/s41592-018-0049-4
# 260077      99999                          10.1038/s41592-018-0049-4
#
# [266069 rows x 2 columns]

# %%
# now remove all of the data that is now located on other tables
neuron_df = neuron_df.drop(['brain_region', 'cell_type', 'experiment_condition', 
                 'domain', 'attributes', 'reference_pmid', 'reference_doi'], axis = 1)
neuron_df.columns
# Out:
# Index(['neuron_id', 'neuron_name', 'archive', 'note', 'age_scale', 'gender',
#        'age_classification', 'species', 'strain', 'scientific_name', 'stain',
#        'protocol', 'slicing_direction', 'reconstruction_software',
#        'objective_type', 'original_format', 'magnification', 'upload_date',
#        'deposition_date', 'shrinkage_reported', 'shrinkage_corrected',
#        'reported_value', 'reported_xy', 'reported_z', 'corrected_value',
#        'corrected_xy', 'corrected_z', 'soma_surface', 'surface', 'volume',
#        'slicing_thickness', 'min_age', 'max_age', 'min_weight', 'max_weight',
#        'png_url', 'physical_Integrity', '_links.self.href',
#        '_links.measurements.href', '_links.persistence_vector.href',
#        'brain_region_len', 'primary_brain_region', 'secondary_brain_region',
#        'tertiary_brain_region', 'dendrites', 'soma', 'axon', 'processes',
#        'neurites', 'att_diameter', 'att_angles', 'att_3D'],
#       dtype='object')

# %% [markdown]
# # morphology

# %%
morpho_df = pd.json_normalize(morpho)

# %%
morpho_df.head(3).T
# Out:
#                             0         1         2
# neuron_name          cnic_001  cnic_002  cnic_003
# surface               8842.91   7257.42   10130.4
# volume                4725.89   3468.16   4742.74
# soma_Surface            834.0   669.819    843.96
# n_stems                   6.0       7.0       6.0
# n_bifs                   47.0      43.0      48.0
# n_branch                100.0      93.0     102.0
# width                 230.779     201.5    330.96
# height                  330.4    298.69    343.73
# depth                   84.73     70.62     80.13
# diameter             0.543665  0.538696  0.505679
# eucDistance           224.624   228.252   238.616
# pathDistance          253.921   258.267   280.686
# branch_Order              8.0       8.0      10.0
# contraction          0.934755  0.933755  0.922649
# fragmentation          1274.0    1033.0    1407.0
# partition_asymmetry  0.413619  0.354564  0.443479
# pk_classic            1.52521   1.49429   1.57966
# bif_ampl_local        33.3799   38.2596   39.1267
# fractal_Dim           1.01989   1.01778   1.02164
# neuron_id                   1         2         3
# bif_ampl_remote        50.461   45.9089   55.7257
# length                 4911.5   4144.17    6222.5

# %% [markdown]
# **This data follows the normal forms. It goes with the neuron table so we can merge the two**

# %%
len(morpho_df)
# Out:
# 260078

# %%
len(neuron_df)
# Out:
# 260078

# %%
test = pd.merge(neuron_df, morpho_df,
        on = ['neuron_id', 'neuron_name'],
        how = 'outer',
        validate = 'one_to_one',
        indicator = True)

# %%
test.query("_merge == 'right_only'")
# Out:
#         neuron_id                    neuron_name archive note age_scale  \
# 260078      51958                         605706     NaN  NaN       NaN
# 260079      54499                   P6-animal1-2     NaN  NaN       NaN
# 260080      78668                    cell-4ca3_2     NaN  NaN       NaN
# 260081     105715             20180701_Pair2_pre     NaN  NaN       NaN
# 260082     105716             20180711_Pair5_pre     NaN  NaN       NaN
# 260083     105717            20180712_Pair7_post     NaN  NaN       NaN
# 260084     105718            20180702_Pair3_post     NaN  NaN       NaN
# 260085     105719            20180701_Pair2_post     NaN  NaN       NaN
# 260086     105720            20180711_Pair5_post     NaN  NaN       NaN
# 260087     105721             20180712_Pair7_pre     NaN  NaN       NaN
# 260088     105722             20180702_Pair3_pre     NaN  NaN       NaN
# 260089     105723            20180712_Pair8_post     NaN  NaN       NaN
# 260090     105724             20180712_Pair8_pre     NaN  NaN       NaN
# 260091     111411                            POC     NaN  NaN       NaN
# 260092     111412             Protocrebrum_right     NaN  NaN       NaN
# 260093     111413  Protocerebrum_extension_right     NaN  NaN       NaN
# 260094     111414   Protocerebrum_extension_left     NaN  NaN       NaN
# 260095     111415             Protocerebrum_left     NaN  NaN       NaN
# 260096     111418           Protocerebrum_bottom     NaN  NaN       NaN
# 260097     111419                  Ocelli_bottom     NaN  NaN       NaN
# 260098     111420                       Ocelli_a     NaN  NaN       NaN
# 260099     111421                       Ocelli_b     NaN  NaN       NaN
# 260100     111422               Medulla_bottom_a     NaN  NaN       NaN
# 260101     111423               Medulla_bottom_b     NaN  NaN       NaN
# 260102     111426                         Loop_b     NaN  NaN       NaN
# 260103     111427                         Loop_a     NaN  NaN       NaN
# 260104     111428                Lobula_bottom_a     NaN  NaN       NaN
# 260105     111429                Lobula_bottom_b     NaN  NaN       NaN
# 260106     111432                Lamina_bottom_a     NaN  NaN       NaN
# 260107     111433           Antennallobus_bottom     NaN  NaN       NaN
# 260108     111434                  Antennallobus     NaN  NaN       NaN
# 260109     123571     918889_Cardona-nona_Others     NaN  NaN       NaN
# 260110     123572    3720037_Cardona-nona_Others     NaN  NaN       NaN
# 260111     123573    5206247_Cardona-nona_Others     NaN  NaN       NaN
# 260112     125801           Green_6weeks_Neuron5     NaN  NaN       NaN
# 260113     132290                        4B4_1_a     NaN  NaN       NaN
# 260114     132294                        4B5_1_a     NaN  NaN       NaN
#
#        gender age_classification species strain scientific_name  ...  \
# 260078    NaN                NaN     NaN    NaN             NaN  ...
# 260079    NaN                NaN     NaN    NaN             NaN  ...
# 260080    NaN                NaN     NaN    NaN             NaN  ...
# 260081    NaN                NaN     NaN    NaN             NaN  ...
# 260082    NaN                NaN     NaN    NaN             NaN  ...
# 260083    NaN                NaN     NaN    NaN             NaN  ...
# 260084    NaN                NaN     NaN    NaN             NaN  ...
# 260085    NaN                NaN     NaN    NaN             NaN  ...
# 260086    NaN                NaN     NaN    NaN             NaN  ...
# 260087    NaN                NaN     NaN    NaN             NaN  ...
# 260088    NaN                NaN     NaN    NaN             NaN  ...
# 260089    NaN                NaN     NaN    NaN             NaN  ...
# 260090    NaN                NaN     NaN    NaN             NaN  ...
# 260091    NaN                NaN     NaN    NaN             NaN  ...
# 260092    NaN                NaN     NaN    NaN             NaN  ...
# 260093    NaN                NaN     NaN    NaN             NaN  ...
# 260094    NaN                NaN     NaN    NaN             NaN  ...
# 260095    NaN                NaN     NaN    NaN             NaN  ...
# 260096    NaN                NaN     NaN    NaN             NaN  ...
# 260097    NaN                NaN     NaN    NaN             NaN  ...
# 260098    NaN                NaN     NaN    NaN             NaN  ...
# 260099    NaN                NaN     NaN    NaN             NaN  ...
# 260100    NaN                NaN     NaN    NaN             NaN  ...
# 260101    NaN                NaN     NaN    NaN             NaN  ...
# 260102    NaN                NaN     NaN    NaN             NaN  ...
# 260103    NaN                NaN     NaN    NaN             NaN  ...
# 260104    NaN                NaN     NaN    NaN             NaN  ...
# 260105    NaN                NaN     NaN    NaN             NaN  ...
# 260106    NaN                NaN     NaN    NaN             NaN  ...
# 260107    NaN                NaN     NaN    NaN             NaN  ...
# 260108    NaN                NaN     NaN    NaN             NaN  ...
# 260109    NaN                NaN     NaN    NaN             NaN  ...
# 260110    NaN                NaN     NaN    NaN             NaN  ...
# 260111    NaN                NaN     NaN    NaN             NaN  ...
# 260112    NaN                NaN     NaN    NaN             NaN  ...
# 260113    NaN                NaN     NaN    NaN             NaN  ...
# 260114    NaN                NaN     NaN    NaN             NaN  ...
#
#        branch_Order contraction fragmentation partition_asymmetry pk_classic  \
# 260078         67.0    0.923130        2134.0            0.675423    1.41085
# 260079          7.0    0.904933         352.0            0.398196    2.00000
# 260080          6.0    0.831715         313.0            0.462963    1.58199
# 260081         11.0    0.901207        4916.0            0.429722    1.64435
# 260082         14.0    0.926870        4248.0            0.480893    3.22361
# 260083         12.0    0.900483        2878.0            0.593584    2.83422
# 260084          7.0    0.910768        9635.0            0.444841    1.24858
# 260085         13.0    0.906014        4265.0            0.582992    2.79937
# 260086         16.0    0.911843        2689.0            0.591481    3.10785
# 260087         13.0    0.914613        3079.0            0.501014    1.63845
# 260088          9.0    0.906264        7481.0            0.463318    1.31437
# 260089          9.0    0.905977        5431.0            0.451039    1.95333
# 260090          9.0    0.917633        5049.0            0.399534    1.42767
# 260091         52.0    0.907017       22962.0            0.676096    2.00000
# 260092        219.0    0.935916        8417.0            0.693409    2.00115
# 260093         16.0    0.919710        4414.0            0.665409    2.00000
# 260094         23.0    0.914630        5638.0            0.690846    2.00000
# 260095        186.0    0.936006        8233.0            0.675171    1.99880
# 260096        148.0    0.962320        6909.0            0.710777    2.00000
# 260097         28.0    0.901885       25056.0            0.652191    2.00000
# 260098         13.0    0.946796        1628.0            0.523497    2.00000
# 260099          8.0    0.968478         882.0            0.461233    2.00000
# 260100        114.0    0.926217        5052.0            0.701411    2.00000
# 260101        113.0    0.940896        5014.0            0.703368    2.00000
# 260102         18.0    0.865233        5557.0            0.664017    2.00000
# 260103         21.0    0.869968        7797.0            0.755283    2.00000
# 260104         17.0    0.839253        6263.0            0.867769    2.00000
# 260105          9.0    0.900630        3393.0            0.638889    2.00000
# 260106        138.0    0.913901        3890.0            0.744084    2.00000
# 260107         39.0    0.853054       12240.0            0.632887    2.00000
# 260108         38.0    0.938335       10776.0            0.689991    2.00000
# 260109         59.0    0.862734        2725.0            0.706415    2.00000
# 260110         69.0    0.864946        5017.0            0.702556    2.00000
# 260111         90.0    0.869654        4454.0            0.709741    2.00000
# 260112          0.0    0.911095          42.0            0.000000    0.00000
# 260113          4.0    0.798424        3338.0            0.426871    1.70214
# 260114          4.0    0.768163        3524.0            0.600000    1.67624
#
#        bif_ampl_local fractal_Dim bif_ampl_remote      length      _merge
# 260078        93.3333     1.09581         91.9344    547.7660  right_only
# 260079        29.0535     1.03612         54.3384    446.4340  right_only
# 260080        89.8503     1.07486         63.6774    524.1770  right_only
# 260081        85.5518     1.03231         65.8053   5696.8700  right_only
# 260082        78.5712     1.02378         66.9350   5747.5900  right_only
# 260083        90.5629     1.03773         79.2214   4530.2100  right_only
# 260084        87.9668     1.02338         78.7374   4642.2800  right_only
# 260085        87.5139     1.03010         72.9552   4994.1200  right_only
# 260086        82.6465     1.03016         73.1698   3134.6700  right_only
# 260087        77.9696     1.02907         65.2235   4244.6100  right_only
# 260088        87.6772     1.02526         71.3582   5930.7000  right_only
# 260089        73.6830     1.03227         67.6470   5066.6500  right_only
# 260090        83.9006     1.02509         72.9430   4522.5000  right_only
# 260091       121.4070     1.02312         98.2508  14438.8000  right_only
# 260092       113.8090     1.03759        107.9890  47131.8000  right_only
# 260093       113.6840     1.01763         91.2604   3376.7900  right_only
# 260094       108.8830     1.02096        104.5640   4326.1200  right_only
# 260095       113.3940     1.04364        107.5550  45232.6000  right_only
# 260096       115.5580     1.01241        109.8270  27379.2000  right_only
# 260097       113.3250     1.02269         95.2119  15970.5000  right_only
# 260098       120.7750     1.01256        108.5390   1322.8400  right_only
# 260099        79.4068     1.00372         50.8036    785.5330  right_only
# 260100       112.1240     1.02439        107.1930  21622.7000  right_only
# 260101       113.5880     1.01990        104.6030  21439.0000  right_only
# 260102       122.1280     1.04695        103.5440   4046.7300  right_only
# 260103       122.9790     1.04048         99.7687   5999.6100  right_only
# 260104       122.9350     1.04897        110.3230   5005.6900  right_only
# 260105       113.5250     1.01619        104.6940   2368.6100  right_only
# 260106       106.8470     1.04123         97.4814  16488.9000  right_only
# 260107       112.3800     1.04048        103.4680   9348.8500  right_only
# 260108       117.9360     1.01425        103.9670   7390.4700  right_only
# 260109        91.3163     1.14494         92.0873    482.3770  right_only
# 260110        94.5723     1.14891         95.3071    827.2000  right_only
# 260111        92.0254     1.15884         92.4624    758.3980  right_only
# 260112         0.0000     1.02673          0.0000     92.8791  right_only
# 260113        77.1502     1.06015         78.5250   2217.0800  right_only
# 260114        87.7822     1.05617         65.0684   2215.4500  right_only
#
# [37 rows x 74 columns]

# %%
test.query("_merge == 'left_only'")
# Out:
#         neuron_id                    neuron_name                  archive  \
# 6230       105715           KW20180701_Pair2_pre                 Yousheng
# 6231       105716           KW20180711_Pair5_pre                 Yousheng
# 6232       105717          KW20180712_Pair7_post                 Yousheng
# 6233       105718          KW20180702_Pair3_post                 Yousheng
# 6234       105719          KW20180701_Pair2_post                 Yousheng
# 6236       105720          KW20180711_Pair5_post                 Yousheng
# 6237       105721           KW20180712_Pair7_pre                 Yousheng
# 6238       105722           KW20180702_Pair3_pre                 Yousheng
# 6239       105723          KW20180712_Pair8_post                 Yousheng
# 6240       105724           KW20180712_Pair8_pre                 Yousheng
# 12090      111411                            poc            Beer_Foerster
# 12091      111412             protocrebrum_right            Beer_Foerster
# 12092      111413  protocerebrum_extension_right            Beer_Foerster
# 12093      111414   protocerebrum_extension_left            Beer_Foerster
# 12094      111415             protocerebrum_left            Beer_Foerster
# 12097      111418           protocerebrum_bottom            Beer_Foerster
# 12098      111419                  ocelli_bottom            Beer_Foerster
# 12100      111420                       ocelli_a            Beer_Foerster
# 12101      111421                       ocelli_b            Beer_Foerster
# 12102      111422               medulla_bottom_a            Beer_Foerster
# 12103      111423               medulla_bottom_b            Beer_Foerster
# 12106      111426                         loop_b            Beer_Foerster
# 12107      111427                         loop_a            Beer_Foerster
# 12108      111428                lobula_bottom_a            Beer_Foerster
# 12109      111429                lobula_bottom_b            Beer_Foerster
# 12113      111432                lamina_bottom_a            Beer_Foerster
# 12114      111433           antennallobus_bottom            Beer_Foerster
# 12115      111434                  antennallobus            Beer_Foerster
# 24597      123571                         918889                  Cardona
# 24598      123572                        3720037                  Cardona
# 24599      123573                        5206247                  Cardona
# 26878      125801           Green_6Weeks_Neuron5  Hrvoj-Mihic_Semendeferi
# 33893      132290                        4b4_1_a                 Ellender
# 33896      132294                        4b5_1_a                 Ellender
# 207719      51958                         525937                    FlyEM
# 210540      54499                   p6-animal1-2                  Kengaku
# 237044      78668                    cell-4CA3_2        Papageorgiou_Kann
#
#                                                      note     age_scale  \
# 6230    Synaptic contact from Pyramidal cell to Pyrami...           Day
# 6231    Synaptic contact from Pyramidal cell to Pyrami...           Day
# 6232    Synaptic contact from Pyramidal cell to Pyrami...           Day
# 6233    Synaptic contact from Pyramidal cell to Pyrami...           Day
# 6234    Synaptic contact from Pyramidal cell to Pyrami...           Day
# 6236    Synaptic contact from Pyramidal cell to Pyrami...           Day
# 6237    Synaptic contact from Pyramidal cell to Pyrami...           Day
# 6238    Synaptic contact from Pyramidal cell to Pyrami...           Day
# 6239    Synaptic contact from Pyramidal cell to Pyrami...           Day
# 6240    Synaptic contact from Pyramidal cell to Pyrami...           Day
# 12090                                                               Day
# 12091                                                               Day
# 12092                                                               Day
# 12093                                                               Day
# 12094                                                               Day
# 12097                                                               Day
# 12098                                                               Day
# 12100                                                               Day
# 12101                                                               Day
# 12102                                                               Day
# 12103                                                               Day
# 12106                                                               Day
# 12107                                                               Day
# 12108                                                               Day
# 12109                                                               Day
# 12113                                                               Day
# 12114                                                               Day
# 12115                                                               Day
# 24597                                          3rd instar  Not Reported
# 24598                                          3rd instar  Not Reported
# 24599                                          3rd instar  Not Reported
# 26878   Brain region refers to grafting target of mous...  Not Reported
# 33893                                                               Day
# 33896                                                               Day
# 207719                                                              Day
# 210540                                                              Day
# 237044                                                     Not Reported
#
#               gender age_classification                  species  \
# 6230     Male/Female        young adult                    mouse
# 6231     Male/Female        young adult                    mouse
# 6232     Male/Female        young adult                    mouse
# 6233     Male/Female        young adult                    mouse
# 6234     Male/Female        young adult                    mouse
# 6236     Male/Female        young adult                    mouse
# 6237     Male/Female        young adult                    mouse
# 6238     Male/Female        young adult                    mouse
# 6239     Male/Female        young adult                    mouse
# 6240     Male/Female        young adult                    mouse
# 12090         Female              adult           Apis mellifera
# 12091         Female              adult           Apis mellifera
# 12092         Female              adult           Apis mellifera
# 12093         Female              adult           Apis mellifera
# 12094         Female              adult           Apis mellifera
# 12097         Female              adult           Apis mellifera
# 12098         Female              adult           Apis mellifera
# 12100         Female              adult           Apis mellifera
# 12101         Female              adult           Apis mellifera
# 12102         Female              adult           Apis mellifera
# 12103         Female              adult           Apis mellifera
# 12106         Female              adult           Apis mellifera
# 12107         Female              adult           Apis mellifera
# 12108         Female              adult           Apis mellifera
# 12109         Female              adult           Apis mellifera
# 12113         Female              adult           Apis mellifera
# 12114         Female              adult           Apis mellifera
# 12115         Female              adult           Apis mellifera
# 24597   Not reported             larval  drosophila melanogaster
# 24598   Not reported             larval  drosophila melanogaster
# 24599   Not reported             larval  drosophila melanogaster
# 26878   Not reported       not reported                    human
# 33893    Male/Female        young adult                    mouse
# 33896    Male/Female        young adult                    mouse
# 207719        Female              adult  drosophila melanogaster
# 210540  Not reported              young                    mouse
# 237044          Male              adult                      rat
#
#                      strain    scientific_name  ... branch_Order contraction  \
# 6230                  C57B6               None  ...          NaN         NaN
# 6231                  C57B6               None  ...          NaN         NaN
# 6232                  C57B6               None  ...          NaN         NaN
# 6233                  C57B6               None  ...          NaN         NaN
# 6234                  C57B6               None  ...          NaN         NaN
# 6236                  C57B6               None  ...          NaN         NaN
# 6237                  C57B6               None  ...          NaN         NaN
# 6238                  C57B6               None  ...          NaN         NaN
# 6239                  C57B6               None  ...          NaN         NaN
# 6240                  C57B6               None  ...          NaN         NaN
# 12090          Not reported               None  ...          NaN         NaN
# 12091          Not reported               None  ...          NaN         NaN
# 12092          Not reported               None  ...          NaN         NaN
# 12093          Not reported               None  ...          NaN         NaN
# 12094          Not reported               None  ...          NaN         NaN
# 12097          Not reported               None  ...          NaN         NaN
# 12098          Not reported               None  ...          NaN         NaN
# 12100          Not reported               None  ...          NaN         NaN
# 12101          Not reported               None  ...          NaN         NaN
# 12102          Not reported               None  ...          NaN         NaN
# 12103          Not reported               None  ...          NaN         NaN
# 12106          Not reported               None  ...          NaN         NaN
# 12107          Not reported               None  ...          NaN         NaN
# 12108          Not reported               None  ...          NaN         NaN
# 12109          Not reported               None  ...          NaN         NaN
# 12113          Not reported               None  ...          NaN         NaN
# 12114          Not reported               None  ...          NaN         NaN
# 12115          Not reported               None  ...          NaN         NaN
# 24597   Canton S G1 x w1118               None  ...          NaN         NaN
# 24598   Canton S G1 x w1118               None  ...          NaN         NaN
# 24599   Canton S G1 x w1118               None  ...          NaN         NaN
# 26878        Not applicable               None  ...          NaN         NaN
# 33893               C57BL/6                     ...          NaN         NaN
# 33896               C57BL/6                     ...          NaN         NaN
# 207719  Canton S G1 x w1118               None  ...          NaN         NaN
# 210540                  ICR               None  ...          NaN         NaN
# 237044               Wistar  rattus norvegicus  ...          NaN         NaN
#
#        fragmentation partition_asymmetry pk_classic bif_ampl_local  \
# 6230             NaN                 NaN        NaN            NaN
# 6231             NaN                 NaN        NaN            NaN
# 6232             NaN                 NaN        NaN            NaN
# 6233             NaN                 NaN        NaN            NaN
# 6234             NaN                 NaN        NaN            NaN
# 6236             NaN                 NaN        NaN            NaN
# 6237             NaN                 NaN        NaN            NaN
# 6238             NaN                 NaN        NaN            NaN
# 6239             NaN                 NaN        NaN            NaN
# 6240             NaN                 NaN        NaN            NaN
# 12090            NaN                 NaN        NaN            NaN
# 12091            NaN                 NaN        NaN            NaN
# 12092            NaN                 NaN        NaN            NaN
# 12093            NaN                 NaN        NaN            NaN
# 12094            NaN                 NaN        NaN            NaN
# 12097            NaN                 NaN        NaN            NaN
# 12098            NaN                 NaN        NaN            NaN
# 12100            NaN                 NaN        NaN            NaN
# 12101            NaN                 NaN        NaN            NaN
# 12102            NaN                 NaN        NaN            NaN
# 12103            NaN                 NaN        NaN            NaN
# 12106            NaN                 NaN        NaN            NaN
# 12107            NaN                 NaN        NaN            NaN
# 12108            NaN                 NaN        NaN            NaN
# 12109            NaN                 NaN        NaN            NaN
# 12113            NaN                 NaN        NaN            NaN
# 12114            NaN                 NaN        NaN            NaN
# 12115            NaN                 NaN        NaN            NaN
# 24597            NaN                 NaN        NaN            NaN
# 24598            NaN                 NaN        NaN            NaN
# 24599            NaN                 NaN        NaN            NaN
# 26878            NaN                 NaN        NaN            NaN
# 33893            NaN                 NaN        NaN            NaN
# 33896            NaN                 NaN        NaN            NaN
# 207719           NaN                 NaN        NaN            NaN
# 210540           NaN                 NaN        NaN            NaN
# 237044           NaN                 NaN        NaN            NaN
#
#        fractal_Dim bif_ampl_remote length     _merge
# 6230           NaN             NaN    NaN  left_only
# 6231           NaN             NaN    NaN  left_only
# 6232           NaN             NaN    NaN  left_only
# 6233           NaN             NaN    NaN  left_only
# 6234           NaN             NaN    NaN  left_only
# 6236           NaN             NaN    NaN  left_only
# 6237           NaN             NaN    NaN  left_only
# 6238           NaN             NaN    NaN  left_only
# 6239           NaN             NaN    NaN  left_only
# 6240           NaN             NaN    NaN  left_only
# 12090          NaN             NaN    NaN  left_only
# 12091          NaN             NaN    NaN  left_only
# 12092          NaN             NaN    NaN  left_only
# 12093          NaN             NaN    NaN  left_only
# 12094          NaN             NaN    NaN  left_only
# 12097          NaN             NaN    NaN  left_only
# 12098          NaN             NaN    NaN  left_only
# 12100          NaN             NaN    NaN  left_only
# 12101          NaN             NaN    NaN  left_only
# 12102          NaN             NaN    NaN  left_only
# 12103          NaN             NaN    NaN  left_only
# 12106          NaN             NaN    NaN  left_only
# 12107          NaN             NaN    NaN  left_only
# 12108          NaN             NaN    NaN  left_only
# 12109          NaN             NaN    NaN  left_only
# 12113          NaN             NaN    NaN  left_only
# 12114          NaN             NaN    NaN  left_only
# 12115          NaN             NaN    NaN  left_only
# 24597          NaN             NaN    NaN  left_only
# 24598          NaN             NaN    NaN  left_only
# 24599          NaN             NaN    NaN  left_only
# 26878          NaN             NaN    NaN  left_only
# 33893          NaN             NaN    NaN  left_only
# 33896          NaN             NaN    NaN  left_only
# 207719         NaN             NaN    NaN  left_only
# 210540         NaN             NaN    NaN  left_only
# 237044         NaN             NaN    NaN  left_only
#
# [37 rows x 74 columns]

# %%
# this is a case where the neuron_ids match but the names don't
morpho_df.query("neuron_id == 105716")
# KW20180701_Pair2_pre
# 20180701_Pair2_pre
# Out:
#                neuron_name  surface   volume  soma_Surface  n_stems  n_bifs  \
# 104354  20180711_Pair5_pre  19739.4  7323.27       507.638      9.0    60.0
#
#         n_branch   width  height  depth  ...  branch_Order  contraction  \
# 104354     129.0  342.16  573.02   33.3  ...          14.0      0.92687
#
#         fragmentation  partition_asymmetry  pk_classic  bif_ampl_local  \
# 104354         4248.0             0.480893     3.22361         78.5712
#
#         fractal_Dim  neuron_id  bif_ampl_remote   length
# 104354      1.02378     105716           66.935  5747.59
#
# [1 rows x 23 columns]

# %%
# look to just merge on neuron_id
id_only = pd.merge(neuron_df, morpho_df,
        on = ['neuron_id'],
        how = 'outer',
        validate = 'one_to_one',
        indicator = True)

# %%
# this worked
id_only.query("_merge == 'right_only'")
# Out:
# Empty DataFrame
# Columns: [neuron_id, neuron_name_x, archive, note, age_scale, gender, age_classification, species, strain, scientific_name, stain, protocol, slicing_direction, reconstruction_software, objective_type, original_format, magnification, upload_date, deposition_date, shrinkage_reported, shrinkage_corrected, reported_value, reported_xy, reported_z, corrected_value, corrected_xy, corrected_z, soma_surface, surface_x, volume_x, slicing_thickness, min_age, max_age, min_weight, max_weight, png_url, physical_Integrity, _links.self.href, _links.measurements.href, _links.persistence_vector.href, brain_region_len, primary_brain_region, secondary_brain_region, tertiary_brain_region, dendrites, soma, axon, processes, neurites, att_diameter, att_angles, att_3D, neuron_name_y, surface_y, volume_y, soma_Surface, n_stems, n_bifs, n_branch, width, height, depth, diameter, eucDistance, pathDistance, branch_Order, contraction, fragmentation, partition_asymmetry, pk_classic, bif_ampl_local, fractal_Dim, bif_ampl_remote, length, _merge]
# Index: []
#
# [0 rows x 75 columns]

# %%
# there's only 37 where there is not a correct name match, I am going to drop the neuron names for y and use just the x ones
len(neuron_df) - sum(id_only['neuron_name_x'] == id_only['neuron_name_y'])
# Out:
# 37

# %%
# do the merge without validation now
neuron_df = pd.merge(neuron_df, morpho_df,
        on = ['neuron_id'],
        how = 'inner')

# %%
# drop the y neuron name and change the neuron_name_x to just neuron_name
neuron_df = neuron_df.drop(['neuron_name_y'], axis = 1)
neuron_df = neuron_df.rename(columns = {'neuron_name_x': 'neuron_name'})
neuron_df.head(3)
# Out:
#    neuron_id neuron_name     archive  \
# 0          1    cnic_001  Wearne_Hof
# 1         10    cnic_041  Wearne_Hof
# 2        100        n419      Turner
#
#                                                 note age_scale       gender  \
# 0  When originally released, this reconstruction ...      Year  Male/Female
# 1  When originally released, this reconstruction ...      Year  Male/Female
# 2  When originally released, this reconstruction ...     Month  Male/Female
#
#   age_classification species       strain    scientific_name  ...  \
# 0                old  monkey       Rhesus     Macaca mulatta  ...
# 1                old  monkey       Rhesus     Macaca mulatta  ...
# 2              young     rat  Fischer 344  rattus norvegicus  ...
#
#   pathDistance branch_Order contraction fragmentation partition_asymmetry  \
# 0      253.921          8.0    0.934755        1274.0            0.413619
# 1      264.030          7.0    0.909303        1038.0            0.410981
# 2     1078.420         19.0    0.772968        4223.0            0.447733
#
#   pk_classic bif_ampl_local fractal_Dim bif_ampl_remote   length
# 0    1.52521        33.3799     1.01989         50.4610   4911.5
# 1    1.99859        66.5523     1.02661         52.7609   3450.3
# 2    1.68693        79.1183     1.04104         57.4892  13143.0
#
# [3 rows x 73 columns]

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    display(neuron_df.head(3).T)
# Out:
#                                                                                 0  \
# neuron_id                                                                       1
# neuron_name                                                              cnic_001
# archive                                                                Wearne_Hof
# note                            When originally released, this reconstruction ...
# age_scale                                                                    Year
# gender                                                                Male/Female
# age_classification                                                            old
# species                                                                    monkey
# strain                                                                     Rhesus
# scientific_name                                                    Macaca mulatta
# stain                                                              lucifer yellow
# protocol                                                                  in vivo
# slicing_direction                                                          custom
# reconstruction_software                                                 Neurozoom
# objective_type                                                       Not reported
# original_format                                                     Neurozoom.swc
# magnification                                                                 100
# upload_date                                                            2006-08-01
# deposition_date                                                        2005-12-31
# shrinkage_reported                                                       Reported
# shrinkage_corrected                                                 Not Corrected
# reported_value                                                               None
# reported_xy                                                                  None
# reported_z                                                                   None
# corrected_value                                                              None
# corrected_xy                                                                 None
# corrected_z                                                                  None
# soma_surface                                                                834.0
# surface_x                                                                 8842.91
# volume_x                                                                  4725.89
# slicing_thickness                                                             400
# min_age                                                                      24.0
# max_age                                                                      25.0
# min_weight                                                                 4500.0
# max_weight                                                                10000.0
# png_url                         http://neuromorpho.org/images/imageFiles/Wearn...
# physical_Integrity                                             Dendrites Moderate
# _links.self.href                           http://neuromorpho.org/api/neuron/id/1
# _links.measurements.href              http://neuromorpho.org/api/morphometry/id/1
# _links.persistence_vector.href               http://neuromorpho.org/api/pvec/id/1
# brain_region_len                                                              3.0
# primary_brain_region                                                    neocortex
# secondary_brain_region                                                 prefrontal
# tertiary_brain_region                                                     layer 3
# dendrites                                                                       1
# soma                                                                            1
# axon                                                                            0
# processes                                                                       0
# neurites                                                                        0
# att_diameter                                                                    1
# att_angles                                                                      1
# att_3D                                                                          1
# surface_y                                                                 8842.91
# volume_y                                                                  4725.89
# soma_Surface                                                                834.0
# n_stems                                                                       6.0
# n_bifs                                                                       47.0
# n_branch                                                                    100.0
# width                                                                     230.779
# height                                                                      330.4
# depth                                                                       84.73
# diameter                                                                 0.543665
# eucDistance                                                               224.624
# pathDistance                                                              253.921
# branch_Order                                                                  8.0
# contraction                                                              0.934755
# fragmentation                                                              1274.0
# partition_asymmetry                                                      0.413619
# pk_classic                                                                1.52521
# bif_ampl_local                                                            33.3799
# fractal_Dim                                                               1.01989
# bif_ampl_remote                                                            50.461
# length                                                                     4911.5
#
#                                                                                 1  \
# neuron_id                                                                      10
# neuron_name                                                              cnic_041
# archive                                                                Wearne_Hof
# note                            When originally released, this reconstruction ...
# age_scale                                                                    Year
# gender                                                                Male/Female
# age_classification                                                            old
# species                                                                    monkey
# strain                                                                     Rhesus
# scientific_name                                                    Macaca mulatta
# stain                                                              lucifer yellow
# protocol                                                                  in vivo
# slicing_direction                                                          custom
# reconstruction_software                                                 Neurozoom
# objective_type                                                       Not reported
# original_format                                                     Neurozoom.swc
# magnification                                                                 100
# upload_date                                                            2006-08-01
# deposition_date                                                        2005-12-31
# shrinkage_reported                                                       Reported
# shrinkage_corrected                                                 Not Corrected
# reported_value                                                               None
# reported_xy                                                                  None
# reported_z                                                                   None
# corrected_value                                                              None
# corrected_xy                                                                 None
# corrected_z                                                                  None
# soma_surface                                                              817.784
# surface_x                                                                 6601.59
# volume_x                                                                  4330.41
# slicing_thickness                                                             400
# min_age                                                                      24.0
# max_age                                                                      25.0
# min_weight                                                                 4500.0
# max_weight                                                                10000.0
# png_url                         http://neuromorpho.org/images/imageFiles/Wearn...
# physical_Integrity                                             Dendrites Moderate
# _links.self.href                          http://neuromorpho.org/api/neuron/id/10
# _links.measurements.href             http://neuromorpho.org/api/morphometry/id/10
# _links.persistence_vector.href              http://neuromorpho.org/api/pvec/id/10
# brain_region_len                                                              3.0
# primary_brain_region                                                    neocortex
# secondary_brain_region                                                 prefrontal
# tertiary_brain_region                                                     layer 3
# dendrites                                                                       1
# soma                                                                            1
# axon                                                                            0
# processes                                                                       0
# neurites                                                                        0
# att_diameter                                                                    1
# att_angles                                                                      1
# att_3D                                                                          1
# surface_y                                                                 6601.59
# volume_y                                                                  4330.41
# soma_Surface                                                              817.784
# n_stems                                                                       5.0
# n_bifs                                                                       31.0
# n_branch                                                                     67.0
# width                                                                     242.062
# height                                                                    312.241
# depth                                                                       57.08
# diameter                                                                 0.572838
# eucDistance                                                               219.892
# pathDistance                                                               264.03
# branch_Order                                                                  7.0
# contraction                                                              0.909303
# fragmentation                                                              1038.0
# partition_asymmetry                                                      0.410981
# pk_classic                                                                1.99859
# bif_ampl_local                                                            66.5523
# fractal_Dim                                                               1.02661
# bif_ampl_remote                                                           52.7609
# length                                                                     3450.3
#
#                                                                                 2
# neuron_id                                                                     100
# neuron_name                                                                  n419
# archive                                                                    Turner
# note                            When originally released, this reconstruction ...
# age_scale                                                                   Month
# gender                                                                Male/Female
# age_classification                                                          young
# species                                                                       rat
# strain                                                                Fischer 344
# scientific_name                                                 rattus norvegicus
# stain                                                                    biocytin
# protocol                                                                  in vivo
# slicing_direction                                                         coronal
# reconstruction_software                                               Neurolucida
# objective_type                                                                oil
# original_format                                                   Neurolucida.swc
# magnification                                                                 100
# upload_date                                                            2006-08-01
# deposition_date                                                        2005-12-31
# shrinkage_reported                                                       Reported
# shrinkage_corrected                                                     Corrected
# reported_value                                                               None
# reported_xy                                                                  25.0
# reported_z                                                                   75.0
# corrected_value                                                              None
# corrected_xy                                                                133.0
# corrected_z                                                                 400.0
# soma_surface                                                              897.846
# surface_x                                                                 23909.3
# volume_x                                                                  4215.04
# slicing_thickness                                                              80
# min_age                                                                       2.0
# max_age                                                                       8.0
# min_weight                                                                  200.0
# max_weight                                                                  350.0
# png_url                         http://neuromorpho.org/images/imageFiles/Turne...
# physical_Integrity                                             Dendrites Complete
# _links.self.href                         http://neuromorpho.org/api/neuron/id/100
# _links.measurements.href            http://neuromorpho.org/api/morphometry/id/100
# _links.persistence_vector.href             http://neuromorpho.org/api/pvec/id/100
# brain_region_len                                                              2.0
# primary_brain_region                                                  hippocampus
# secondary_brain_region                                                        CA1
# tertiary_brain_region                                                        None
# dendrites                                                                       1
# soma                                                                            1
# axon                                                                            0
# processes                                                                       0
# neurites                                                                        0
# att_diameter                                                                    1
# att_angles                                                                      1
# att_3D                                                                          1
# surface_y                                                                 23909.3
# volume_y                                                                  4215.04
# soma_Surface                                                              897.846
# n_stems                                                                       5.0
# n_bifs                                                                       75.0
# n_branch                                                                    155.0
# width                                                                     249.098
# height                                                                    611.318
# depth                                                                      205.03
# diameter                                                                 0.556778
# eucDistance                                                               529.358
# pathDistance                                                              1078.42
# branch_Order                                                                 19.0
# contraction                                                              0.772968
# fragmentation                                                              4223.0
# partition_asymmetry                                                      0.447733
# pk_classic                                                                1.68693
# bif_ampl_local                                                            79.1183
# fractal_Dim                                                               1.04104
# bif_ampl_remote                                                           57.4892
# length                                                                    13143.0

# %% [markdown]
# **neuron_df is now set to be put in the database**

# %% [markdown]
# # electro

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    display(electro.head().T)
# Out:
#                                                                        0  \
# Index                                                                150
# Title                  Cell type-specific effects of adenosine on cor...
# Pmid                                                            24108800
# PubYear                                                             2015
# LastAuthor                                                   Feldmeyer D
# ArticleID                                                          88449
# TableID                                                          35984.0
# NeuronName                                         Neocortex basket cell
# NeuronLongName          medial prefrontal cortex fast spiking interne...
# NeuronPrefName          medial prefrontal cortex fast spiking interne...
# NeuroNERAnnots         [ABA_REGION:714, HBP_EPHYS:0000080, HBP_EPHYS_...
# BrainRegion                                                    Isocortex
# MetadataCurated                                                     True
# Species                                                             Rats
# Strain                                                      Rats, Wistar
# ElectrodeType                                                Patch-clamp
# PrepType                                                        in vitro
# JxnPotential                                                  Unreported
# JxnOffset                                                            NaN
# RecTemp                                                             30.0
# AnimalAge                                                      33.226495
# AnimalWeight                                                         NaN
# FlagSoln                                                             NaN
# ExternalSolution       Slices were stored for up to 8 h in ACSF conta...
# ExternalSolution_conf                                                5.0
# external_0_Mg                                                        1.0
# external_0_Ca                                                        2.0
# external_0_Na                                                     151.25
# external_0_Cl                                                      131.5
# external_0_K                                                         2.5
# external_0_pH                                                        NaN
# InternalSolution       Patch pipettes (4-8 MÎ©) were pulled from thic...
# InternalSolution_conf                                                5.0
# internal_0_Mg                                                        4.0
# internal_0_Ca                                                        NaN
# internal_0_Na                                                       20.3
# internal_0_Cl                                                        4.0
# internal_0_K                                                       139.0
# internal_0_pH                                                        7.3
# MetadataNote                                                         NaN
# TableNote              there are 3 different ISI ratios; I only used ...
# rin                                                                178.0
# rin_raw                                                            178.0
# rin_err                                                             11.0
# rin_n                                                               14.0
# rin_sd                                                         41.158231
# rin_note                                                             NaN
# rmp                                                                -72.2
# rmp_raw                                                            -72.2
# rmp_err                                                              1.3
# rmp_n                                                               14.0
# rmp_sd                                                          4.864155
# rmp_note                                                             NaN
# apthr                                                                NaN
# apthr_raw                                                            NaN
# apthr_err                                                            NaN
# apthr_n                                                              NaN
# apthr_sd                                                             NaN
# apthr_note                                                           NaN
# apamp                                                                NaN
# apamp_raw                                                            NaN
# apamp_err                                                            NaN
# apamp_n                                                              NaN
# apamp_sd                                                             NaN
# apamp_note                                                           NaN
# aphw                                                                0.38
# aphw_raw                                                            0.38
# aphw_err                                                            0.03
# aphw_n                                                              14.0
# aphw_sd                                                          0.11225
# aphw_note                                                            NaN
# tau                                                                  7.9
# tau_raw                                                              7.9
# tau_err                                                              0.5
# tau_n                                                               14.0
# tau_sd                                                          1.870829
# tau_note                                                             NaN
# ahpamp                                                               NaN
# ahpamp_raw                                                           NaN
# ahpamp_err                                                           NaN
# ahpamp_n                                                             NaN
# ahpamp_sd                                                            NaN
# ahpamp_note                                                          NaN
# cap                                                                  NaN
# cap_raw                                                              NaN
# cap_err                                                              NaN
# cap_n                                                                NaN
# cap_sd                                                               NaN
# cap_note                                                             NaN
# apwidth                                                              NaN
# apwidth_raw                                                          NaN
# apwidth_err                                                          NaN
# apwidth_n                                                            NaN
# apwidth_sd                                                           NaN
# apwidth_note                                                         NaN
# apfreq                                                               NaN
# apfreq_raw                                                           NaN
# apfreq_err                                                           NaN
# apfreq_n                                                             NaN
# apfreq_sd                                                            NaN
# apfreq_note                                                          NaN
# rheo                                                               176.0
# rheo_raw                                                           176.0
# rheo_err                                                            15.0
# rheo_n                                                              14.0
# rheo_sd                                                        56.124861
# rheo_note                                                            NaN
# ahpdur                                                               NaN
# ahpdur_raw                                                           NaN
# ahpdur_err                                                           NaN
# ahpdur_n                                                             NaN
# ahpdur_sd                                                            NaN
# ahpdur_note                                                          NaN
# sagratio                                                             NaN
# sagratio_raw                                                         NaN
# sagratio_err                                                         NaN
# sagratio_n                                                           NaN
# sagratio_sd                                                          NaN
# sagratio_note                                                        NaN
# maxfreq                                                              NaN
# maxfreq_raw                                                          NaN
# maxfreq_err                                                          NaN
# maxfreq_n                                                            NaN
# maxfreq_sd                                                           NaN
# maxfreq_note                                                         NaN
# apriseslope                                                          NaN
# apriseslope_raw                                                      NaN
# apriseslope_err                                                      NaN
# apriseslope_n                                                        NaN
# apriseslope_sd                                                       NaN
# apriseslope_note                                                     NaN
# fahpamp                                                              NaN
# fahpamp_raw                                                          NaN
# fahpamp_err                                                          NaN
# fahpamp_n                                                            NaN
# fahpamp_sd                                                           NaN
# fahpamp_note                                                         NaN
# spontfreq                                                            NaN
# spontfreq_raw                                                        NaN
# spontfreq_err                                                        NaN
# spontfreq_n                                                          NaN
# spontfreq_sd                                                         NaN
# spontfreq_note                                                       NaN
# appeak                                                               NaN
# appeak_raw                                                           NaN
# appeak_err                                                           NaN
# appeak_n                                                             NaN
# appeak_sd                                                            NaN
# appeak_note                                                          NaN
# apriset                                                              NaN
# apriset_raw                                                          NaN
# apriset_err                                                          NaN
# apriset_n                                                            NaN
# apriset_sd                                                           NaN
# apriset_note                                                         NaN
# apdecayslope                                                         NaN
# apdecayslope_raw                                                     NaN
# apdecayslope_err                                                     NaN
# apdecayslope_n                                                       NaN
# apdecayslope_sd                                                      NaN
# apdecayslope_note                                                    NaN
# apdelay                                                              NaN
# apdelay_raw                                                          NaN
# apdelay_err                                                          NaN
# apdelay_n                                                            NaN
# apdelay_sd                                                           NaN
# apdelay_note                                                         NaN
# fislope                                                              NaN
# fislope_raw                                                         40.9
# fislope_err                                                          NaN
# fislope_n                                                            NaN
# fislope_sd                                                           NaN
# fislope_note                                                         NaN
# adratio                                                             0.96
# adratio_raw                                                         0.96
# adratio_err                                                         0.04
# adratio_n                                                           14.0
# adratio_sd                                                      0.149666
# adratio_note                                                         NaN
# apamprest                                                            NaN
# apamprest_raw                                                        NaN
# apamprest_err                                                        NaN
# apamprest_n                                                          NaN
# apamprest_sd                                                         NaN
# apamprest_note                                                       NaN
# other                                                                NaN
# other_raw                                                            NaN
# other_err                                                            NaN
# other_n                                                              NaN
# other_sd                                                             NaN
# other_note                                                           NaN
# sagamp                                                               NaN
# sagamp_raw                                                           NaN
# sagamp_err                                                           NaN
# sagamp_n                                                             NaN
# sagamp_sd                                                            NaN
# sagamp_note                                                          NaN
# sahpamp                                                              NaN
# sahpamp_raw                                                          NaN
# sahpamp_err                                                          NaN
# sahpamp_n                                                            NaN
# sahpamp_sd                                                           NaN
# sahpamp_note                                                         NaN
# apdecayt                                                             NaN
# apdecayt_raw                                                         NaN
# apdecayt_err                                                         NaN
# apdecayt_n                                                           NaN
# apdecayt_sd                                                          NaN
# apdecayt_note                                                        NaN
# accres                                                               NaN
# accres_raw                                                           NaN
# accres_err                                                           NaN
# accres_n                                                             NaN
# accres_sd                                                            NaN
# accres_note                                                          NaN
# adratioinv                                                           NaN
# adratioinv_raw                                                       NaN
# adratioinv_err                                                       NaN
# adratioinv_n                                                         NaN
# adratioinv_sd                                                        NaN
# adratioinv_note                                                      NaN
# adpamp                                                               NaN
# adpamp_raw                                                           NaN
# adpamp_err                                                           NaN
# adpamp_n                                                             NaN
# adpamp_sd                                                            NaN
# adpamp_note                                                          NaN
# ahpamprest                                                           NaN
# ahpamprest_raw                                                       NaN
# ahpamprest_err                                                       NaN
# ahpamprest_n                                                         NaN
# ahpamprest_sd                                                        NaN
# ahpamprest_note                                                      NaN
# mahpamp                                                              NaN
# mahpamp_raw                                                          NaN
# mahpamp_err                                                          NaN
# mahpamp_n                                                            NaN
# mahpamp_sd                                                           NaN
# mahpamp_note                                                         NaN
# fahpdur                                                              NaN
# fahpdur_raw                                                          NaN
# fahpdur_err                                                          NaN
# fahpdur_n                                                            NaN
# fahpdur_sd                                                           NaN
# fahpdur_note                                                         NaN
# ahpvolt                                                              NaN
# ahpvolt_raw                                                          NaN
# ahpvolt_err                                                          NaN
# ahpvolt_n                                                            NaN
# ahpvolt_sd                                                           NaN
# ahpvolt_note                                                         NaN
# sahpdur                                                              NaN
# sahpdur_raw                                                          NaN
# sahpdur_err                                                          NaN
# sahpdur_n                                                            NaN
# sahpdur_sd                                                           NaN
# sahpdur_note                                                         NaN
# celldiam                                                             NaN
# celldiam_raw                                                         NaN
# celldiam_err                                                         NaN
# celldiam_n                                                           NaN
# celldiam_sd                                                          NaN
# celldiam_note                                                        NaN
# adpctother                                                           NaN
# adpctother_raw                                                       NaN
# adpctother_err                                                       NaN
# adpctother_n                                                         NaN
# adpctother_sd                                                        NaN
# adpctother_note                                                      NaN
# adpct                                                                NaN
# adpct_raw                                                            NaN
# adpct_err                                                            NaN
# adpct_n                                                              NaN
# adpct_sd                                                             NaN
# adpct_note                                                           NaN
# adpctminus                                                           NaN
# adpctminus_raw                                                       NaN
# adpctminus_err                                                       NaN
# adpctminus_n                                                         NaN
# adpctminus_sd                                                        NaN
# adpctminus_note                                                      NaN
# surfarea                                                             NaN
# surfarea_raw                                                         NaN
# surfarea_err                                                         NaN
# surfarea_n                                                           NaN
# surfarea_sd                                                          NaN
# surfarea_note                                                        NaN
# mahpdur                                                              NaN
# mahpdur_raw                                                          NaN
# mahpdur_err                                                          NaN
# mahpdur_n                                                            NaN
# mahpdur_sd                                                           NaN
# mahpdur_note                                                         NaN
# adratiominus                                                         NaN
# adratiominus_raw                                                     NaN
# adratiominus_err                                                     NaN
# adratiominus_n                                                       NaN
# adratiominus_sd                                                      NaN
# adratiominus_note                                                    NaN
# adpctinv                                                             NaN
# adpctinv_raw                                                         NaN
# adpctinv_err                                                         NaN
# adpctinv_n                                                           NaN
# adpctinv_sd                                                          NaN
# adpctinv_note                                                        NaN
# adpdur                                                               NaN
# adpdur_raw                                                           NaN
# adpdur_err                                                           NaN
# adpdur_n                                                             NaN
# adpdur_sd                                                            NaN
# adpdur_note                                                          NaN
# fahpvolt                                                             NaN
# fahpvolt_raw                                                         NaN
# fahpvolt_err                                                         NaN
# fahpvolt_n                                                           NaN
# fahpvolt_sd                                                          NaN
# fahpvolt_note                                                        NaN
# mahpamprest                                                          NaN
# mahpamprest_raw                                                      NaN
# mahpamprest_err                                                      NaN
# mahpamprest_n                                                        NaN
# mahpamprest_sd                                                       NaN
# mahpamprest_note                                                     NaN
# apamptrough                                                          NaN
# apamptrough_raw                                                      NaN
# apamptrough_err                                                      NaN
# apamptrough_n                                                        NaN
# apamptrough_sd                                                       NaN
# apamptrough_note                                                     NaN
# sahpamprest                                                          NaN
# sahpamprest_raw                                                      NaN
# sahpamprest_err                                                      NaN
# sahpamprest_n                                                        NaN
# sahpamprest_sd                                                       NaN
# sahpamprest_note                                                     NaN
# fahpamprest                                                          NaN
# fahpamprest_raw                                                      NaN
# fahpamprest_err                                                      NaN
# fahpamprest_n                                                        NaN
# fahpamprest_sd                                                       NaN
# fahpamprest_note                                                     NaN
# sahpvolt                                                             NaN
# sahpvolt_raw                                                         NaN
# sahpvolt_err                                                         NaN
# sahpvolt_n                                                           NaN
# sahpvolt_sd                                                          NaN
# sahpvolt_note                                                        NaN
# mahpvolt                                                             NaN
# mahpvolt_raw                                                         NaN
# mahpvolt_err                                                         NaN
# mahpvolt_n                                                           NaN
# mahpvolt_sd                                                          NaN
# mahpvolt_note                                                        NaN
#
#                                                                        1  \
# Index                                                                149
# Title                  Cell type-specific effects of adenosine on cor...
# Pmid                                                            24108800
# PubYear                                                             2015
# LastAuthor                                                   Feldmeyer D
# ArticleID                                                          88449
# TableID                                                          35984.0
# NeuronName                                     Neocortex Martinotti cell
# NeuronLongName         medial prefrontal cortex low-threshold spiking...
# NeuronPrefName         medial prefrontal cortex low-threshold spiking...
# NeuroNERAnnots         [ABA_REGION:714, HBP_EPHYS:0000110, HBP_EPHYS_...
# BrainRegion                                                    Isocortex
# MetadataCurated                                                     True
# Species                                                             Rats
# Strain                                                      Rats, Wistar
# ElectrodeType                                                Patch-clamp
# PrepType                                                        in vitro
# JxnPotential                                                  Unreported
# JxnOffset                                                            NaN
# RecTemp                                                             30.0
# AnimalAge                                                      33.226495
# AnimalWeight                                                         NaN
# FlagSoln                                                             NaN
# ExternalSolution       Slices were stored for up to 8 h in ACSF conta...
# ExternalSolution_conf                                                5.0
# external_0_Mg                                                        1.0
# external_0_Ca                                                        2.0
# external_0_Na                                                     151.25
# external_0_Cl                                                      131.5
# external_0_K                                                         2.5
# external_0_pH                                                        NaN
# InternalSolution       Patch pipettes (4-8 MÎ©) were pulled from thic...
# InternalSolution_conf                                                5.0
# internal_0_Mg                                                        4.0
# internal_0_Ca                                                        NaN
# internal_0_Na                                                       20.3
# internal_0_Cl                                                        4.0
# internal_0_K                                                       139.0
# internal_0_pH                                                        7.3
# MetadataNote                                                         NaN
# TableNote              there are 3 different ISI ratios; I only used ...
# rin                                                                361.0
# rin_raw                                                            361.0
# rin_err                                                             58.0
# rin_n                                                                5.0
# rin_sd                                                        129.691943
# rin_note                                                             NaN
# rmp                                                                -66.3
# rmp_raw                                                            -66.3
# rmp_err                                                              1.9
# rmp_n                                                                5.0
# rmp_sd                                                          4.248529
# rmp_note                                                             NaN
# apthr                                                                NaN
# apthr_raw                                                            NaN
# apthr_err                                                            NaN
# apthr_n                                                              NaN
# apthr_sd                                                             NaN
# apthr_note                                                           NaN
# apamp                                                                NaN
# apamp_raw                                                            NaN
# apamp_err                                                            NaN
# apamp_n                                                              NaN
# apamp_sd                                                             NaN
# apamp_note                                                           NaN
# aphw                                                                0.79
# aphw_raw                                                            0.79
# aphw_err                                                            0.05
# aphw_n                                                               5.0
# aphw_sd                                                         0.111803
# aphw_note                                                            NaN
# tau                                                                 27.4
# tau_raw                                                             27.4
# tau_err                                                              5.2
# tau_n                                                                5.0
# tau_sd                                                         11.627553
# tau_note                                                             NaN
# ahpamp                                                               NaN
# ahpamp_raw                                                           NaN
# ahpamp_err                                                           NaN
# ahpamp_n                                                             NaN
# ahpamp_sd                                                            NaN
# ahpamp_note                                                          NaN
# cap                                                                  NaN
# cap_raw                                                              NaN
# cap_err                                                              NaN
# cap_n                                                                NaN
# cap_sd                                                               NaN
# cap_note                                                             NaN
# apwidth                                                              NaN
# apwidth_raw                                                          NaN
# apwidth_err                                                          NaN
# apwidth_n                                                            NaN
# apwidth_sd                                                           NaN
# apwidth_note                                                         NaN
# apfreq                                                               NaN
# apfreq_raw                                                           NaN
# apfreq_err                                                           NaN
# apfreq_n                                                             NaN
# apfreq_sd                                                            NaN
# apfreq_note                                                          NaN
# rheo                                                                28.0
# rheo_raw                                                            28.0
# rheo_err                                                             9.0
# rheo_n                                                               5.0
# rheo_sd                                                        20.124612
# rheo_note                                                            NaN
# ahpdur                                                               NaN
# ahpdur_raw                                                           NaN
# ahpdur_err                                                           NaN
# ahpdur_n                                                             NaN
# ahpdur_sd                                                            NaN
# ahpdur_note                                                          NaN
# sagratio                                                             NaN
# sagratio_raw                                                         NaN
# sagratio_err                                                         NaN
# sagratio_n                                                           NaN
# sagratio_sd                                                          NaN
# sagratio_note                                                        NaN
# maxfreq                                                              NaN
# maxfreq_raw                                                          NaN
# maxfreq_err                                                          NaN
# maxfreq_n                                                            NaN
# maxfreq_sd                                                           NaN
# maxfreq_note                                                         NaN
# apriseslope                                                          NaN
# apriseslope_raw                                                      NaN
# apriseslope_err                                                      NaN
# apriseslope_n                                                        NaN
# apriseslope_sd                                                       NaN
# apriseslope_note                                                     NaN
# fahpamp                                                              NaN
# fahpamp_raw                                                          NaN
# fahpamp_err                                                          NaN
# fahpamp_n                                                            NaN
# fahpamp_sd                                                           NaN
# fahpamp_note                                                         NaN
# spontfreq                                                            NaN
# spontfreq_raw                                                        NaN
# spontfreq_err                                                        NaN
# spontfreq_n                                                          NaN
# spontfreq_sd                                                         NaN
# spontfreq_note                                                       NaN
# appeak                                                               NaN
# appeak_raw                                                           NaN
# appeak_err                                                           NaN
# appeak_n                                                             NaN
# appeak_sd                                                            NaN
# appeak_note                                                          NaN
# apriset                                                              NaN
# apriset_raw                                                          NaN
# apriset_err                                                          NaN
# apriset_n                                                            NaN
# apriset_sd                                                           NaN
# apriset_note                                                         NaN
# apdecayslope                                                         NaN
# apdecayslope_raw                                                     NaN
# apdecayslope_err                                                     NaN
# apdecayslope_n                                                       NaN
# apdecayslope_sd                                                      NaN
# apdecayslope_note                                                    NaN
# apdelay                                                              NaN
# apdelay_raw                                                          NaN
# apdelay_err                                                          NaN
# apdelay_n                                                            NaN
# apdelay_sd                                                           NaN
# apdelay_note                                                         NaN
# fislope                                                              NaN
# fislope_raw                                                         13.6
# fislope_err                                                          NaN
# fislope_n                                                            NaN
# fislope_sd                                                           NaN
# fislope_note                                                         NaN
# adratio                                                             0.43
# adratio_raw                                                         0.43
# adratio_err                                                         0.09
# adratio_n                                                            5.0
# adratio_sd                                                      0.201246
# adratio_note                                                         NaN
# apamprest                                                            NaN
# apamprest_raw                                                        NaN
# apamprest_err                                                        NaN
# apamprest_n                                                          NaN
# apamprest_sd                                                         NaN
# apamprest_note                                                       NaN
# other                                                                NaN
# other_raw                                                            NaN
# other_err                                                            NaN
# other_n                                                              NaN
# other_sd                                                             NaN
# other_note                                                           NaN
# sagamp                                                               NaN
# sagamp_raw                                                           NaN
# sagamp_err                                                           NaN
# sagamp_n                                                             NaN
# sagamp_sd                                                            NaN
# sagamp_note                                                          NaN
# sahpamp                                                              NaN
# sahpamp_raw                                                          NaN
# sahpamp_err                                                          NaN
# sahpamp_n                                                            NaN
# sahpamp_sd                                                           NaN
# sahpamp_note                                                         NaN
# apdecayt                                                             NaN
# apdecayt_raw                                                         NaN
# apdecayt_err                                                         NaN
# apdecayt_n                                                           NaN
# apdecayt_sd                                                          NaN
# apdecayt_note                                                        NaN
# accres                                                               NaN
# accres_raw                                                           NaN
# accres_err                                                           NaN
# accres_n                                                             NaN
# accres_sd                                                            NaN
# accres_note                                                          NaN
# adratioinv                                                           NaN
# adratioinv_raw                                                       NaN
# adratioinv_err                                                       NaN
# adratioinv_n                                                         NaN
# adratioinv_sd                                                        NaN
# adratioinv_note                                                      NaN
# adpamp                                                               NaN
# adpamp_raw                                                           NaN
# adpamp_err                                                           NaN
# adpamp_n                                                             NaN
# adpamp_sd                                                            NaN
# adpamp_note                                                          NaN
# ahpamprest                                                           NaN
# ahpamprest_raw                                                       NaN
# ahpamprest_err                                                       NaN
# ahpamprest_n                                                         NaN
# ahpamprest_sd                                                        NaN
# ahpamprest_note                                                      NaN
# mahpamp                                                              NaN
# mahpamp_raw                                                          NaN
# mahpamp_err                                                          NaN
# mahpamp_n                                                            NaN
# mahpamp_sd                                                           NaN
# mahpamp_note                                                         NaN
# fahpdur                                                              NaN
# fahpdur_raw                                                          NaN
# fahpdur_err                                                          NaN
# fahpdur_n                                                            NaN
# fahpdur_sd                                                           NaN
# fahpdur_note                                                         NaN
# ahpvolt                                                              NaN
# ahpvolt_raw                                                          NaN
# ahpvolt_err                                                          NaN
# ahpvolt_n                                                            NaN
# ahpvolt_sd                                                           NaN
# ahpvolt_note                                                         NaN
# sahpdur                                                              NaN
# sahpdur_raw                                                          NaN
# sahpdur_err                                                          NaN
# sahpdur_n                                                            NaN
# sahpdur_sd                                                           NaN
# sahpdur_note                                                         NaN
# celldiam                                                             NaN
# celldiam_raw                                                         NaN
# celldiam_err                                                         NaN
# celldiam_n                                                           NaN
# celldiam_sd                                                          NaN
# celldiam_note                                                        NaN
# adpctother                                                           NaN
# adpctother_raw                                                       NaN
# adpctother_err                                                       NaN
# adpctother_n                                                         NaN
# adpctother_sd                                                        NaN
# adpctother_note                                                      NaN
# adpct                                                                NaN
# adpct_raw                                                            NaN
# adpct_err                                                            NaN
# adpct_n                                                              NaN
# adpct_sd                                                             NaN
# adpct_note                                                           NaN
# adpctminus                                                           NaN
# ...
# spontfreq_n                                                          NaN
# spontfreq_sd                                                         NaN
# spontfreq_note                                                       NaN
# appeak                                                               NaN
# appeak_raw                                                           NaN
# appeak_err                                                           NaN
# appeak_n                                                             NaN
# appeak_sd                                                            NaN
# appeak_note                                                          NaN
# apriset                                                             0.98
# apriset_raw                                                         0.98
# apriset_err                                                         0.04
# apriset_n                                                           26.0
# apriset_sd                                                      0.203961
# apriset_note                                                         NaN
# apdecayslope                                                         NaN
# apdecayslope_raw                                                     NaN
# apdecayslope_err                                                     NaN
# apdecayslope_n                                                       NaN
# apdecayslope_sd                                                      NaN
# apdecayslope_note                                                    NaN
# apdelay                                                              NaN
# apdelay_raw                                                          NaN
# apdelay_err                                                          NaN
# apdelay_n                                                            NaN
# apdelay_sd                                                           NaN
# apdelay_note                                                         NaN
# fislope                                                              NaN
# fislope_raw                                                          NaN
# fislope_err                                                          NaN
# fislope_n                                                            NaN
# fislope_sd                                                           NaN
# fislope_note                                                         NaN
# adratio                                                              NaN
# adratio_raw                                                          NaN
# adratio_err                                                          NaN
# adratio_n                                                            NaN
# adratio_sd                                                           NaN
# adratio_note                                                         NaN
# apamprest                                                            NaN
# apamprest_raw                                                        NaN
# apamprest_err                                                        NaN
# apamprest_n                                                          NaN
# apamprest_sd                                                         NaN
# apamprest_note                                                       NaN
# other                                                                NaN
# other_raw                                                            NaN
# other_err                                                            NaN
# other_n                                                              NaN
# other_sd                                                             NaN
# other_note                                                           NaN
# sagamp                                                               NaN
# sagamp_raw                                                           NaN
# sagamp_err                                                           NaN
# sagamp_n                                                             NaN
# sagamp_sd                                                            NaN
# sagamp_note                                                          NaN
# sahpamp                                                             1.71
# sahpamp_raw                                                        -1.71
# sahpamp_err                                                         0.28
# sahpamp_n                                                           26.0
# sahpamp_sd                                                      1.427725
# sahpamp_note                                                         NaN
# apdecayt                                                            2.27
# apdecayt_raw                                                        2.27
# apdecayt_err                                                         0.1
# apdecayt_n                                                          26.0
# apdecayt_sd                                                     0.509902
# apdecayt_note                                                        NaN
# accres                                                               NaN
# accres_raw                                                           NaN
# accres_err                                                           NaN
# accres_n                                                             NaN
# accres_sd                                                            NaN
# accres_note                                                          NaN
# adratioinv                                                           NaN
# adratioinv_raw                                                       NaN
# adratioinv_err                                                       NaN
# adratioinv_n                                                         NaN
# adratioinv_sd                                                        NaN
# adratioinv_note                                                      NaN
# adpamp                                                               NaN
# adpamp_raw                                                           NaN
# adpamp_err                                                           NaN
# adpamp_n                                                             NaN
# adpamp_sd                                                            NaN
# adpamp_note                                                          NaN
# ahpamprest                                                           NaN
# ahpamprest_raw                                                       NaN
# ahpamprest_err                                                       NaN
# ahpamprest_n                                                         NaN
# ahpamprest_sd                                                        NaN
# ahpamprest_note                                                      NaN
# mahpamp                                                             9.93
# mahpamp_raw                                                        -9.93
# mahpamp_err                                                         0.37
# mahpamp_n                                                           26.0
# mahpamp_sd                                                      1.886637
# mahpamp_note                                                         NaN
# fahpdur                                                              NaN
# fahpdur_raw                                                          NaN
# fahpdur_err                                                          NaN
# fahpdur_n                                                            NaN
# fahpdur_sd                                                           NaN
# fahpdur_note                                                         NaN
# ahpvolt                                                              NaN
# ahpvolt_raw                                                          NaN
# ahpvolt_err                                                          NaN
# ahpvolt_n                                                            NaN
# ahpvolt_sd                                                           NaN
# ahpvolt_note                                                         NaN
# sahpdur                                                            659.0
# sahpdur_raw                                                        659.0
# sahpdur_err                                                         42.0
# sahpdur_n                                                           26.0
# sahpdur_sd                                                     214.15882
# sahpdur_note                                                         NaN
# celldiam                                                             NaN
# celldiam_raw                                                         NaN
# celldiam_err                                                         NaN
# celldiam_n                                                           NaN
# celldiam_sd                                                          NaN
# celldiam_note                                                        NaN
# adpctother                                                           NaN
# adpctother_raw                                                       NaN
# adpctother_err                                                       NaN
# adpctother_n                                                         NaN
# adpctother_sd                                                        NaN
# adpctother_note                                                      NaN
# adpct                                                                NaN
# adpct_raw                                                            NaN
# adpct_err                                                            NaN
# adpct_n                                                              NaN
# adpct_sd                                                             NaN
# adpct_note                                                           NaN
# adpctminus                                                           NaN
# adpctminus_raw                                                       NaN
# adpctminus_err                                                       NaN
# adpctminus_n                                                         NaN
# adpctminus_sd                                                        NaN
# adpctminus_note                                                      NaN
# surfarea                                                             NaN
# surfarea_raw                                                         NaN
# surfarea_err                                                         NaN
# surfarea_n                                                           NaN
# surfarea_sd                                                          NaN
# surfarea_note                                                        NaN
# mahpdur                                                             52.6
# mahpdur_raw                                                         52.6
# mahpdur_err                                                          6.5
# mahpdur_n                                                           26.0
# mahpdur_sd                                                     33.143627
# mahpdur_note                                                         NaN
# adratiominus                                                         NaN
# adratiominus_raw                                                     NaN
# adratiominus_err                                                     NaN
# adratiominus_n                                                       NaN
# adratiominus_sd                                                      NaN
# adratiominus_note                                                    NaN
# adpctinv                                                             NaN
# adpctinv_raw                                                         NaN
# adpctinv_err                                                         NaN
# adpctinv_n                                                           NaN
# adpctinv_sd                                                          NaN
# adpctinv_note                                                        NaN
# adpdur                                                               NaN
# adpdur_raw                                                           NaN
# adpdur_err                                                           NaN
# adpdur_n                                                             NaN
# adpdur_sd                                                            NaN
# adpdur_note                                                          NaN
# fahpvolt                                                             NaN
# fahpvolt_raw                                                         NaN
# fahpvolt_err                                                         NaN
# fahpvolt_n                                                           NaN
# fahpvolt_sd                                                          NaN
# fahpvolt_note                                                        NaN
# mahpamprest                                                          NaN
# mahpamprest_raw                                                      NaN
# mahpamprest_err                                                      NaN
# mahpamprest_n                                                        NaN
# mahpamprest_sd                                                       NaN
# mahpamprest_note                                                     NaN
# apamptrough                                                          NaN
# apamptrough_raw                                                      NaN
# apamptrough_err                                                      NaN
# apamptrough_n                                                        NaN
# apamptrough_sd                                                       NaN
# apamptrough_note                                                     NaN
# sahpamprest                                                          NaN
# sahpamprest_raw                                                      NaN
# sahpamprest_err                                                      NaN
# sahpamprest_n                                                        NaN
# sahpamprest_sd                                                       NaN
# sahpamprest_note                                                     NaN
# fahpamprest                                                          NaN
# fahpamprest_raw                                                      NaN
# fahpamprest_err                                                      NaN
# fahpamprest_n                                                        NaN
# fahpamprest_sd                                                       NaN
# fahpamprest_note                                                     NaN
# sahpvolt                                                             NaN
# sahpvolt_raw                                                         NaN
# sahpvolt_err                                                         NaN
# sahpvolt_n                                                           NaN
# sahpvolt_sd                                                          NaN
# sahpvolt_note                                                        NaN
# mahpvolt                                                             NaN
# mahpvolt_raw                                                         NaN
# mahpvolt_err                                                         NaN
# mahpvolt_n                                                           NaN
# mahpvolt_sd                                                          NaN
# mahpvolt_note                                                        NaN

# %% [markdown]
# ## Notes on Normal Forms
# * Atomic form violated
#     * NeuroNERAnnots
# * Can remove the values for the paper because they do not depend on the index

# %% [markdown]
# #### NeuroNERAnnots

# %%
# the lists are stored as string, I am not sure what these values mean and there is not documentation
electro['NeuroNERAnnots'][0]
# Out:
# '[ABA_REGION:714, HBP_EPHYS:0000080, HBP_EPHYS_TRIGGER:0000003, NeuronTrigger:interneuron]'

# %%
# find columns that are entirely nan values
empty = []
for i in electro.columns:
    # checking if fully null
    if sum(electro[i].isnull()) == len(electro):
        empty += [i]

# %%
empty
# Out:
# ['FlagSoln',
#  'sagamp_note',
#  'surfarea_note',
#  'mahpdur_note',
#  'adpctinv_note',
#  'adpdur_note',
#  'mahpamprest_note',
#  'sahpamprest_note',
#  'fahpamprest_note',
#  'sahpvolt',
#  'sahpvolt_raw',
#  'sahpvolt_err',
#  'sahpvolt_n',
#  'sahpvolt_sd',
#  'sahpvolt_note',
#  'mahpvolt',
#  'mahpvolt_raw',
#  'mahpvolt_err',
#  'mahpvolt_n',
#  'mahpvolt_sd',
#  'mahpvolt_note']

# %%
drop_cols = ['NeuroNERAnnots'] + empty

# %%
# drop the NeuroNERAnnots and mahpvolt_note
electro = electro.drop(drop_cols, axis = 1)

# %%
electro[['Pmid', 'ArticleID']].drop_duplicates(['Pmid', 'ArticleID'])
# Out:
#           Pmid  ArticleID
# 0     24108800      88449
# 4     24323499      88469
# 6     24554724      88596
# 8     24904071      88491
# 10    25450961      92581
# ...        ...        ...
# 1510   7807199      32143
# 1511   8229799      39223
# 1512   2558172      85547
# 1513   3309264      44985
# 1514   6737292      46161
#
# [749 rows x 2 columns]

# %%
# table is not unique to the Pmid, keep on the electro table

# %%
electro_pub = electro[['Pmid', 'ArticleID','Title', 'PubYear', 'LastAuthor']].drop_duplicates(['Pmid', 'ArticleID'])
electro_pub
# Out:
#           Pmid  ArticleID                                              Title  \
# 0     24108800      88449  Cell type-specific effects of adenosine on cor...
# 4     24323499      88469  Age-related changes to layer 3 pyramidal cells...
# 6     24554724      88596  Transient Hearing Loss Within a Critical Perio...
# 8     24904071      88491  Functional Maturation of GABA Synapses During ...
# 10    25450961      92581  Developmental increase in hyperpolarization-ac...
# ...        ...        ...                                                ...
# 1510   7807199      32143  Electrophysiology of globus pallidus neurons i...
# 1511   8229799      39223  Membrane properties of rat suprachiasmatic nuc...
# 1512   2558172      85547  Intrinsic properties of nucleus reticularis th...
# 1513   3309264      44985  The ventral and dorsal lateral geniculate nucl...
# 1514   6737292      46161  Electrophysiological properties of guinea-pig ...
#
#       PubYear   LastAuthor
# 0        2015  Feldmeyer D
# 4        2015     Peters A
# 6        2015     Sanes DH
# 8        2015     Lewis DA
# 10       2015   Kitamura K
# ...       ...          ...
# 1510     1994    LlinÃ¡s R
# 1511     1993     Dudek FE
# 1512     1989  Spreafico R
# 1513     1987    Pirchio M
# 1514     1984    LlinÃ¡s R
#
# [749 rows x 5 columns]

# %%
electro_pub['Pmid'] = electro_pub['Pmid'].astype('object')

# %%
electro = electro.drop(['Title', 'PubYear', 'LastAuthor', 'ArticleID'], axis = 1)
electro.head(3).T
# Out:
#                                                                  0  \
# Index                                                          150
# Pmid                                                      24108800
# TableID                                                    35984.0
# NeuronName                                   Neocortex basket cell
# NeuronLongName    medial prefrontal cortex fast spiking interne...
# ...                                                            ...
# fahpamprest                                                    NaN
# fahpamprest_raw                                                NaN
# fahpamprest_err                                                NaN
# fahpamprest_n                                                  NaN
# fahpamprest_sd                                                 NaN
#
#                                                                  1  \
# Index                                                          149
# Pmid                                                      24108800
# TableID                                                    35984.0
# NeuronName                               Neocortex Martinotti cell
# NeuronLongName   medial prefrontal cortex low-threshold spiking...
# ...                                                            ...
# fahpamprest                                                    NaN
# fahpamprest_raw                                                NaN
# fahpamprest_err                                                NaN
# fahpamprest_n                                                  NaN
# fahpamprest_sd                                                 NaN
#
#                                                             2
# Index                                                     151
# Pmid                                                 24108800
# TableID                                               35984.0
# NeuronName                              Neocortex basket cell
# NeuronLongName   somatosensory cortex fast-firing interneuron
# ...                                                       ...
# fahpamprest                                               NaN
# fahpamprest_raw                                           NaN
# fahpamprest_err                                           NaN
# fahpamprest_n                                             NaN
# fahpamprest_sd                                            NaN
#
# [327 rows x 3 columns]

# %%
electro['BrainRegion'].value_counts()
# Out:
# BrainRegion
# Isocortex                380
# Hippocampal formation    279
# Striatum                 110
# Medulla                   73
# Olfactory areas           61
# Midbrain                  53
# Thalamus                  36
# Cerebellum                35
# Pallidum                  34
# Cortical subplate         22
# Hypothalamus              17
# Name: count, dtype: int64

# %%
# make BrainRegion lowercase
def lowercase(x):
    try:
        return x.lower()
    except:
        return None
electro['BrainRegion'] = electro['BrainRegion'].apply(lambda x: lowercase(x))
electro['Species'] = electro['Species'].apply(lambda x: lowercase(x))

# %%
unique_electro_regions = [x for x in pd.unique(electro['BrainRegion'])]

# %%
unique_neuron_regions = [x for x in pd.unique(neuron_df['primary_brain_region'])]

# %%
unique_neuron_regions
# Out:
# ['neocortex',
#  'hippocampus',
#  'somatic nervous system',
#  'basal ganglia',
#  'ventral striatum',
#  'cerebellum',
#  'peripheral nervous system',
#  'lateral line organ',
#  'ventral nerve cord',
#  'main olfactory bulb',
#  'spinal cord',
#  'mesencephalon',
#  'retina',
#  'forebrain',
#  'optic lobe',
#  'posterior',
#  'antennal lobe',
#  'lateral',
#  'accessory lobe',
#  'subesophageal ganglion',
#  'protocerebrum',
#  'subesophageal zone-(SEZ)',
#  'basal forebrain',
#  'brainstem',
#  'amygdala',
#  'subiculum',
#  'pallium',
#  'myelencephalon',
#  'anterior olfactory nucleus',
#  'pons',
#  'Central nervous system',
#  'adult subesophageal zone',
#  'hypothalamus',
#  'thalamus',
#  'Central complex',
#  'Right Adult Central Complex',
#  'Left Adult Central Complex',
#  'Pro-subiculum',
#  'stomatogastric ganglion',
#  'Right Mushroom Body',
#  'ventrolateral neuropils',
#  'Left Mushroom Body',
#  'lateral horn',
#  'olfactory cortex',
#  'ventral thalamus',
#  'parasubiculum',
#  'entorhinal cortex',
#  'columns of the fornix',
#  'fornix',
#  'corpus callosum',
#  'cerebral ganglion',
#  'ventrolateral zone',
#  'right',
#  'subpallium',
#  'ganglion',
#  'antenna',
#  'retinorecipient mesencephalon and diencephalon',
#  None,
#  'cortex',
#  'Cochlea',
#  'meninges',
#  'Subventricular zone',
#  'lateral complex',
#  'accessory olfactory bulb',
#  'medulla',
#  'endocrine system',
#  'abdominal ganglion',
#  'Pre-subiculum',
#  'Periventricular region',
#  'mitral layer',
#  'anterior',
#  'eye circuit',
#  'left',
#  'peptidergic circuit',
#  'ciliary band III',
#  'olfactory pit',
#  'pharyngeal nervous system']

# %%
results = []
for i in unique_electro_regions:
    data = {'region': i, 'in_neuron_df': (i in neuron_df)}
    results += [data]

# %%
results
# Out:
# [{'region': 'isocortex', 'in_neuron_df': False},
#  {'region': None, 'in_neuron_df': False},
#  {'region': 'midbrain', 'in_neuron_df': False},
#  {'region': 'hippocampal formation', 'in_neuron_df': False},
#  {'region': 'thalamus', 'in_neuron_df': False},
#  {'region': 'striatum', 'in_neuron_df': False},
#  {'region': 'pallidum', 'in_neuron_df': False},
#  {'region': 'cortical subplate', 'in_neuron_df': False},
#  {'region': 'olfactory areas', 'in_neuron_df': False},
#  {'region': 'medulla', 'in_neuron_df': False},
#  {'region': 'cerebellum', 'in_neuron_df': False},
#  {'region': 'hypothalamus', 'in_neuron_df': False}]

# %%
# check if the neuron_df merges on the electro dataset with species
# can match on zebrafish and goldfish, not very helpful
test_merge = pd.merge(neuron_df, electro,
        left_on = 'species',
        right_on = 'Species',
        how = 'left',
        indicator = True)
test_merge.query("_merge == 'both'")['species'].value_counts()
# Out:
# species
# zebrafish    6021
# goldfish      117
# Name: count, dtype: int64

# %%
# check if the neuron_df merges on the electro dataset with brain region
# keeps killing my kernel
#test_merge = pd.merge(neuron_df, electro,
        #left_on = 'primary_brain_region',
        #right_on = 'BrainRegion',
        #how = 'inner')

# %%
electro.rename({'Index': 'electro_id'}, axis = 1, inplace = True)

# %%
electro_pub.rename({'Index': 'electro_id'}, axis = 1, inplace = True)

# %% [markdown]
# # models

# %%
models_df = pd.json_normalize(models)

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    display(models_df.head(3).T)
# Out:
#                                                                                 0  \
# id                                                                            279
# name                            Low Threshold Calcium Currents in TC cells (De...
# created                                                       2001-01-01T00:00:00
# ver_number                                                                     24
# ver_date                                                      2015-01-02T22:01:45
# class_id                                                                       19
# gitrepo                                                                      True
# notes.value                     In Destexhe, Neubig, Ulrich, and Huguenard (19...
# notes.attr_id                                                                24.0
# neurons.value                   [{'object_id': 262, 'object_name': 'Thalamus g...
# neurons.attr_id                                                              25.0
# currents.value                  [{'object_id': 242, 'object_name': 'I Na,t'}, ...
# currents.attr_id                                                             27.0
# model_type.value                [{'object_id': 3537, 'object_name': 'Neuron or...
# model_type.attr_id                                                          112.0
# model_concept.value             [{'object_id': 3629, 'object_name': 'Dendritic...
# model_concept.attr_id                                                       113.0
# modeling_application.value         [{'object_id': 1882, 'object_name': 'NEURON'}]
# modeling_application.attr_id                                                114.0
# model_paper.value               [{'object_id': 4161, 'object_name': 'Destexhe ...
# model_paper.attr_id                                                         155.0
# implemented_by.value            [{'object_id': 33744, 'object_name': 'Destexhe...
# implemented_by.attr_id                                                      299.0
# simPFid.value                                                               275.0
# simPFid.attr_id                                                             488.0
# has_modelview.value                                                          True
# has_modelview.attr_id                                                       502.0
# hide_autolaunch_button.value                                                False
# hide_autolaunch_button.attr_id                                              582.0
# runprotocols.value              [{'object_id': 181344, 'object_name': '279_4'}...
# runprotocols.attr_id                                                        613.0
# modelviews.all                  [{'name': 'Burst behavior in single-compartmen...
# modelviews.default                                                          279_1
# receptors.value                                                               NaN
# receptors.attr_id                                                             NaN
# region.value                                                                  NaN
# region.attr_id                                                                NaN
# neurotransmitters.value                                                       NaN
# neurotransmitters.attr_id                                                     NaN
# gap_junctions.value                                                           NaN
# gap_junctions.attr_id                                                         NaN
# gene.value                                                                    NaN
# gene.attr_id                                                                  NaN
# opensourcebrain.value                                                         NaN
# alternative_version.value                                                     NaN
# alternative_version.attr_id                                                   NaN
# default_file_notes.value                                                      NaN
# default_file_notes.attr_id                                                    NaN
# species.value                                                                 NaN
# species.attr_id                                                               NaN
# other_concept.value                                                           NaN
# other_concept.attr_id                                                         NaN
# other_simulator.value                                                         NaN
# other_simulator.attr_id                                                       NaN
# biosimulations.value                                                          NaN
# other_type.value                                                              NaN
# other_type.attr_id                                                            NaN
# other_neurons.value                                                           NaN
# other_neurons.attr_id                                                         NaN
# other_currents.value                                                          NaN
# other_currents.attr_id                                                        NaN
# other_implementer.value                                                       NaN
# other_implementer.attr_id                                                     NaN
# other_receptors.value                                                         NaN
# other_receptors.attr_id                                                       NaN
# public_submitter_email.value                                                  NaN
# public_submitter_email.attr_id                                                NaN
# citation.value                                                                NaN
# citation.attr_id                                                              NaN
# other_neurotransmitter.value                                                  NaN
# other_neurotransmitter.attr_id                                                NaN
# other_gene.value                                                              NaN
# other_gene.attr_id                                                            NaN
# public_submitter_name.value                                                   NaN
# public_submitter_name.attr_id                                                 NaN
# icg_channel_details.value                                                     NaN
# icg_channel_details.attr_id                                                   NaN
# license                                                                       NaN
# expmotivation                                                                 NaN
# _citation_text                                                                NaN
# _implementers_text                                                            NaN
#
#                                                                                 1  \
# id                                                                           2487
# name                                   Olfactory Mitral Cell (Davison et al 2000)
# created                                                       2001-04-05T22:35:35
# ver_number                                                                     14
# ver_date                                                    2022-05-27T18:13:12.8
# class_id                                                                       19
# gitrepo                                                                     False
# notes.value                     A four-compartment model of a mammalian olfact...
# notes.attr_id                                                                24.0
# neurons.value                   [{'object_id': 267, 'object_name': 'Olfactory ...
# neurons.attr_id                                                              25.0
# currents.value                  [{'object_id': 242, 'object_name': 'I Na,t'}, ...
# currents.attr_id                                                             27.0
# model_type.value                [{'object_id': 3537, 'object_name': 'Neuron or...
# model_type.attr_id                                                          112.0
# model_concept.value             [{'object_id': 3637, 'object_name': 'Parameter...
# model_concept.attr_id                                                       113.0
# modeling_application.value         [{'object_id': 1882, 'object_name': 'NEURON'}]
# modeling_application.attr_id                                                114.0
# model_paper.value               [{'object_id': 4036, 'object_name': 'Davison A...
# model_paper.attr_id                                                         155.0
# implemented_by.value            [{'object_id': 33739, 'object_name': 'Davison,...
# implemented_by.attr_id                                                      299.0
# simPFid.value                                                               304.0
# simPFid.attr_id                                                             488.0
# has_modelview.value                                                          True
# has_modelview.attr_id                                                       502.0
# hide_autolaunch_button.value                                                False
# hide_autolaunch_button.attr_id                                              582.0
# runprotocols.value              [{'object_id': 181441, 'object_name': '2487_4'...
# runprotocols.attr_id                                                        613.0
# modelviews.all                  [{'name': 'Stimulate soma with 0.2 uA/cm2', 'i...
# modelviews.default                                                         2487_1
# receptors.value                                                               NaN
# receptors.attr_id                                                             NaN
# region.value                                                                  NaN
# region.attr_id                                                                NaN
# neurotransmitters.value                                                       NaN
# neurotransmitters.attr_id                                                     NaN
# gap_junctions.value                                                           NaN
# gap_junctions.attr_id                                                         NaN
# gene.value                                                                    NaN
# gene.attr_id                                                                  NaN
# opensourcebrain.value                                                         NaN
# alternative_version.value                                                     NaN
# alternative_version.attr_id                                                   NaN
# default_file_notes.value                                                      NaN
# default_file_notes.attr_id                                                    NaN
# species.value                                                                 NaN
# species.attr_id                                                               NaN
# other_concept.value                                                           NaN
# other_concept.attr_id                                                         NaN
# other_simulator.value                                                         NaN
# other_simulator.attr_id                                                       NaN
# biosimulations.value                                                          NaN
# other_type.value                                                              NaN
# other_type.attr_id                                                            NaN
# other_neurons.value                                                           NaN
# other_neurons.attr_id                                                         NaN
# other_currents.value                                                          NaN
# other_currents.attr_id                                                        NaN
# other_implementer.value                                                       NaN
# other_implementer.attr_id                                                     NaN
# other_receptors.value                                                         NaN
# other_receptors.attr_id                                                       NaN
# public_submitter_email.value                                                  NaN
# public_submitter_email.attr_id                                                NaN
# citation.value                                                                NaN
# citation.attr_id                                                              NaN
# other_neurotransmitter.value                                                  NaN
# other_neurotransmitter.attr_id                                                NaN
# other_gene.value                                                              NaN
# other_gene.attr_id                                                            NaN
# public_submitter_name.value                                                   NaN
# public_submitter_name.attr_id                                                 NaN
# icg_channel_details.value                                                     NaN
# icg_channel_details.attr_id                                                   NaN
# license                                                                       NaN
# expmotivation                                                                 NaN
# _citation_text                                                                NaN
# _implementers_text                                                            NaN
#
#                                                                                 2
# id                                                                           2488
# name                            Influence of dendritic structure on neocortica...
# created                                                       2001-04-05T22:36:18
# ver_number                                                                     24
# ver_date                                                  2018-11-16T15:29:16.747
# class_id                                                                       19
# gitrepo                                                                      True
# notes.value                     This package contains compartmental models of ...
# notes.attr_id                                                                24.0
# neurons.value                   [{'object_id': 265, 'object_name': 'Neocortex ...
# neurons.attr_id                                                              25.0
# currents.value                  [{'object_id': 242, 'object_name': 'I Na,t'}, ...
# currents.attr_id                                                             27.0
# model_type.value                [{'object_id': 3537, 'object_name': 'Neuron or...
# model_type.attr_id                                                          112.0
# model_concept.value             [{'object_id': 3543, 'object_name': 'Activity ...
# model_concept.attr_id                                                       113.0
# modeling_application.value         [{'object_id': 1882, 'object_name': 'NEURON'}]
# modeling_application.attr_id                                                114.0
# model_paper.value               [{'object_id': 4252, 'object_name': 'Mainen ZF...
# model_paper.attr_id                                                         155.0
# implemented_by.value            [{'object_id': 33763, 'object_name': 'Mainen, ...
# implemented_by.attr_id                                                      299.0
# simPFid.value                                                               315.0
# simPFid.attr_id                                                             488.0
# has_modelview.value                                                          True
# has_modelview.attr_id                                                       502.0
# hide_autolaunch_button.value                                                False
# hide_autolaunch_button.attr_id                                              582.0
# runprotocols.value              [{'object_id': 181358, 'object_name': '2488_4'...
# runprotocols.attr_id                                                        613.0
# modelviews.all                  [{'name': '1a. L3 Aspiny', 'id': '2488_1'}, {'...
# modelviews.default                                                         2488_4
# receptors.value                                                               NaN
# receptors.attr_id                                                             NaN
# region.value                                                                  NaN
# region.attr_id                                                                NaN
# neurotransmitters.value                                                       NaN
# neurotransmitters.attr_id                                                     NaN
# gap_junctions.value                                                           NaN
# gap_junctions.attr_id                                                         NaN
# gene.value                                                                    NaN
# gene.attr_id                                                                  NaN
# opensourcebrain.value                                                         NaN
# alternative_version.value                                                     NaN
# alternative_version.attr_id                                                   NaN
# default_file_notes.value                                                      NaN
# default_file_notes.attr_id                                                    NaN
# species.value                                                                 NaN
# species.attr_id                                                               NaN
# other_concept.value                                                           NaN
# other_concept.attr_id                                                         NaN
# other_simulator.value                                                         NaN
# other_simulator.attr_id                                                       NaN
# biosimulations.value                                                          NaN
# other_type.value                                                              NaN
# other_type.attr_id                                                            NaN
# other_neurons.value                                                           NaN
# other_neurons.attr_id                                                         NaN
# other_currents.value                                                          NaN
# other_currents.attr_id                                                        NaN
# other_implementer.value                                                       NaN
# other_implementer.attr_id                                                     NaN
# other_receptors.value                                                         NaN
# other_receptors.attr_id                                                       NaN
# public_submitter_email.value                                                  NaN
# public_submitter_email.attr_id                                                NaN
# citation.value                                                                NaN
# citation.attr_id                                                              NaN
# other_neurotransmitter.value                                                  NaN
# other_neurotransmitter.attr_id                                                NaN
# other_gene.value                                                              NaN
# other_gene.attr_id                                                            NaN
# public_submitter_name.value                                                   NaN
# public_submitter_name.attr_id                                                 NaN
# icg_channel_details.value                                                     NaN
# icg_channel_details.attr_id                                                   NaN
# license                                                                       NaN
# expmotivation                                                                 NaN
# _citation_text                                                                NaN
# _implementers_text                                                            NaN

# %% [markdown]
# Looking at this data frame, it is just a list of json objects that allows it to combine to other values from different API calls. I should only keep the values for the data I have or am interested in. The table doesn't make a lot of sense without joining onto the other tables from other endpoints. I want to keep the models table as just the ID and unique information though.
#
# Right now I have data for the cell types, regions, and papers. I could get more data for the other tables I find interesting though.
#
# #### List of additional data to get:
# *  neurons
# *  concetps
# *  implemented
# *  views
# *  currents

# %%
def normalize_json_objects(df, column, column_names):
    '''
    df = data frame to expand
    column = column to expand
    column_names = names for new data frame to be returned
    '''
    values = []
    for index, row in df.iterrows():
        try:
            id = row['id']
            data = pd.json_normalize(row[column])
            data['id'] = pd.Series([id] * len(data))
            values += data.values.tolist()
        except:
            pass
    return pd.DataFrame(values, columns = column_names)

# %%
model_currents_df = normalize_json_objects(models_df, 'currents.value', ['model_current_id', 'model_current_name', 'model_id'])

model_neurons_df = normalize_json_objects(models_df, 'neurons.value', ['model_neuron_ids', 'neuron_name', 'model_id'])

model_types_df = normalize_json_objects(models_df, 'model_type.value', ['model_type_id', 'model_type_name', 'model_id'])

model_concepts_df = normalize_json_objects(models_df, 'model_concept.value', ['model_concept_ids', 'model_concept_name', 'model_id'])

model_applications_df = normalize_json_objects(models_df, 'modeling_application.value', ['model_application_ids', 'model_application_name', 'model_id'])

model_paper_df = normalize_json_objects(models_df, 'model_paper.value', ['model_paper_id', 'model_paper_name', 'model_id'])

model_runprotocols_df = normalize_json_objects(models_df, 'runprotocols.value', ['model_runprotocols_id', 'model_runprotocols_name', 'model_id'])

model_implemented_df = normalize_json_objects(models_df, 'implemented_by.value', ['model_implemented_id', 'model_implemented_name', 'model_id'])

model_views_df = normalize_json_objects(models_df, 'modelviews.all', ['model_views_name', 'model_id'])

model_region_df = normalize_json_objects(models_df, 'region.value', ['model_region_id', 'model_region_name', 'model_id'])

model_transmitter_df = normalize_json_objects(models_df, 'neurotransmitters.value', ['model_transmitter_id', 'model_transmitter_name', 'model_id'])

model_species_df = normalize_json_objects(models_df, 'species.value', ['model_species_id', 'model_species_name', 'model_id'])

# %%
# model_runprotocols_name was just the model_id with subscripts
model_runprotocols_df = model_runprotocols_df[['model_runprotocols_id', 'model_id']]

# %%
# remove the columns from the models_df, most are just reminants of the json

models_df = models_df[['id', 'name', 'created', 'ver_number', 'ver_date', 'class_id', 'gitrepo']]

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    display(models_df.head(3).T)
# Out:
#                                                             0  \
# id                                                        279
# name        Low Threshold Calcium Currents in TC cells (De...
# created                                   2001-01-01T00:00:00
# ver_number                                                 24
# ver_date                                  2015-01-02T22:01:45
# class_id                                                   19
# gitrepo                                                  True
#
#                                                      1  \
# id                                                2487
# name        Olfactory Mitral Cell (Davison et al 2000)
# created                            2001-04-05T22:35:35
# ver_number                                          14
# ver_date                         2022-05-27T18:13:12.8
# class_id                                            19
# gitrepo                                          False
#
#                                                             2
# id                                                       2488
# name        Influence of dendritic structure on neocortica...
# created                                   2001-04-05T22:36:18
# ver_number                                                 24
# ver_date                              2018-11-16T15:29:16.747
# class_id                                                   19
# gitrepo                                                  True

# %%
model_currents_df
# Out:
#       model_current_id  model_current_name  model_id
# 0                  242              I Na,t       279
# 1                  245   I T low threshold       279
# 2                  248                 I K       279
# 3                  242              I Na,t      2487
# 4                  243  I L high threshold      2487
# ...                ...                 ...       ...
# 4729               253              I K,Ca   2015414
# 4730               248                 I K   2014996
# 4731               241              I Na,p   2014996
# 4732            137264               I trp   2015413
# 4733            137264               I trp   2015412
#
# [4734 rows x 3 columns]

# %% [markdown]
# # celltypes

# %% [markdown]
# **has neuro_electro data and url to search for neuro_morpho**

# %%
celltypes_df = pd.json_normalize(celltypes)

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    display(celltypes_df.head(3).T)
# Out:
#                                                                          0  \
# id                                                                     257
# name                                        Dentate gyrus granule GLU cell
# created                                                2000-06-23T00:00:00
# ver_number                                                            13.0
# ver_date                                           2015-12-18T11:13:46.103
# class_id                                                                18
# Picture.value            [{'file_name': '', 'file_ext': 'gif', 'file_mi...
# Picture.attr_id                                                       22.0
# Can_Form_type.value      [{'object_id': 285, 'object_name': 'Canonical ...
# Can_Form_type.attr_id                                                 48.0
# Picture_from.value       Lomo, Patterns of activation in a monosynaptic...
# Picture_from.attr_id                                                  81.0
# organism.value           [{'object_id': 3455, 'object_name': 'Vertebrat...
# organism.attr_id                                                     111.0
# neuron_category.value    [{'object_id': 3826, 'object_name': 'principal'}]
# neuron_category.attr_id                                              142.0
# neurontype.value         [{'object_id': 186902, 'object_name': 'Granula...
# neurontype.attr_id                                                   624.0
# rotation.value                                                        90.0
# rotation.attr_id                                                     620.0
# coordinates_2d.value                                               399,122
# coordinates_2d.attr_id                                               618.0
# description.value        The principal neuron of the fascia dentata of ...
# description.attr_id                                                  408.0
# neuroelectro.value                                                      66
# neuroelectro.attr_id                                                 507.0
# neurolex.value                                                         NaN
# neurolex.attr_id                                                       NaN
# interlex.value                                                         NaN
# neuromorpho_url.value                                                  NaN
# hodology.value                                                         NaN
# hodology.attr_id                                                       NaN
# layer.value                                                            NaN
# layer.attr_id                                                          NaN
#
#                                                                          1  \
# id                                                                     258
# name                                    Hippocampus CA1 pyramidal GLU cell
# created                                                2000-06-23T00:00:00
# ver_number                                                            17.0
# ver_date                                            2015-12-18T11:11:51.99
# class_id                                                                18
# Picture.value            [{'file_name': 'newCA1.gif', 'file_ext': 'gif'...
# Picture.attr_id                                                       22.0
# Can_Form_type.value      [{'object_id': 86121, 'object_name': 'Canonica...
# Can_Form_type.attr_id                                                 48.0
# Picture_from.value        cell <a href="http://neuromorpho.org/neuroMor...
# Picture_from.attr_id                                                  81.0
# organism.value           [{'object_id': 3455, 'object_name': 'Vertebrat...
# organism.attr_id                                                     111.0
# neuron_category.value    [{'object_id': 3826, 'object_name': 'principal'}]
# neuron_category.attr_id                                              142.0
# neurontype.value         [{'object_id': 186901, 'object_name': 'Pyramid...
# neurontype.attr_id                                                   624.0
# rotation.value                                                       180.0
# rotation.attr_id                                                     620.0
# coordinates_2d.value                                               234,-15
# coordinates_2d.attr_id                                               618.0
# description.value        The principal neuron of region CA1 of the hipp...
# description.attr_id                                                  408.0
# neuroelectro.value                                                      85
# neuroelectro.attr_id                                                 507.0
# neurolex.value                              Hippocampus_CA1_pyramidal_cell
# neurolex.attr_id                                                     528.0
# interlex.value                                                 ilx_0105031
# neuromorpho_url.value    https://neuromorpho.org/MetaDataResult.jsp?cou...
# hodology.value                                                         NaN
# hodology.attr_id                                                       NaN
# layer.value                                                            NaN
# layer.attr_id                                                          NaN
#
#                                                                          2
# id                                                                     259
# name                                    Hippocampus CA3 pyramidal GLU cell
# created                                                2000-06-23T00:00:00
# ver_number                                                            13.0
# ver_date                                           2015-12-18T11:12:17.647
# class_id                                                                18
# Picture.value            [{'file_name': '', 'file_ext': 'gif', 'file_mi...
# Picture.attr_id                                                       22.0
# Can_Form_type.value      [{'object_id': 291, 'object_name': 'Canonical ...
# Can_Form_type.attr_id                                                 48.0
# Picture_from.value       GM Shepherd, Synaptic Organization of the Brai...
# Picture_from.attr_id                                                  81.0
# organism.value           [{'object_id': 3455, 'object_name': 'Vertebrat...
# organism.attr_id                                                     111.0
# neuron_category.value    [{'object_id': 3826, 'object_name': 'principal'}]
# neuron_category.attr_id                                              142.0
# neurontype.value         [{'object_id': 186901, 'object_name': 'Pyramid...
# neurontype.attr_id                                                   624.0
# rotation.value                                                        45.0
# rotation.attr_id                                                     620.0
# coordinates_2d.value                                                 84,87
# coordinates_2d.attr_id                                               618.0
# description.value        The principal neuron of region CA3 of the hipp...
# description.attr_id                                                  408.0
# neuroelectro.value                                                      89
# neuroelectro.attr_id                                                 507.0
# neurolex.value                              Hippocampus_CA3_pyramidal_cell
# neurolex.attr_id                                                     528.0
# interlex.value                                                         NaN
# neuromorpho_url.value                                                  NaN
# hodology.value                                                         NaN
# hodology.attr_id                                                       NaN
# layer.value                                                            NaN
# layer.attr_id                                                          NaN

# %%
len(celltypes_df)
# Out:
# 278

# %%
# neuroelectro.value may be the link
celltypes_df['neuroelectro.value'].value_counts()
# Out:
# neuroelectro.value
# 99         3
# 209        2
# 111        2
# 110        2
# 66         1
# 177        1
# 233        1
# 78         1
# 184        1
# 21         1
# 115        1
# 148        1
# 128        1
# 130        1
# 40         1
# 175        1
# 85         1
# 37         1
# 18         1
# 150        1
# 135        1
# 129        1
# 190        1
# 194        1
# 183        1
# 117        1
# 89         1
# passive    1
# Name: count, dtype: int64

# %%
electro.query("electro_id == 507")
# Out:
#      electro_id      Pmid  TableID                  NeuronName  \
# 115         507  24592213  27442.0  Dentate gyrus granule cell
#
#                                         NeuronLongName  \
# 115  Dentate gyrus more mature granule cell with ov...
#
#                                         NeuronPrefName            BrainRegion  \
# 115  Dentate gyrus more mature granule cell with ov...  hippocampal formation
#
#      MetadataCurated Species  Strain  ... sahpamprest sahpamprest_raw  \
# 115             True    rats  Wistar  ...         NaN             NaN
#
#     sahpamprest_err  sahpamprest_n  sahpamprest_sd  fahpamprest  \
# 115             NaN            NaN             NaN          NaN
#
#      fahpamprest_raw fahpamprest_err  fahpamprest_n  fahpamprest_sd
# 115              NaN             NaN            NaN             NaN
#
# [1 rows x 327 columns]

# %%
celltypes_df['neuromorpho_url.value']
# Out:
# 0                                                    NaN
# 1      https://neuromorpho.org/MetaDataResult.jsp?cou...
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
#                              ...
# 273                                                  NaN
# 274                                                  NaN
# 275                                                  NaN
# 276                                                  NaN
# 277                                                  NaN
# Name: neuromorpho_url.value, Length: 278, dtype: object

# %%
# these names are too specific to match on with the neurons
celltypes_df['name']
# Out:
# 0                         Dentate gyrus granule GLU cell
# 1                     Hippocampus CA1 pyramidal GLU cell
# 2                     Hippocampus CA3 pyramidal GLU cell
# 3      Neostriatum medium spiny direct pathway GABA cell
# 4                 Substantia nigra pars compacta DA cell
#                              ...
# 273                           Spinal cord Ia interneuron
# 274                 Dopaminergic substantia nigra neuron
# 275                            Vestibular nucleus neuron
# 276                    Barrel cortex L2/3 pyramidal cell
# 277                                 Pancreatic Beta Cell
# Name: name, Length: 278, dtype: object

# %%
# columns to keep
# id, name, neuroelectro.attr_id, description.value, neurolex.value
celltypes_df = celltypes_df[['id', 'name', 'neuroelectro.attr_id', 'description.value', 'neurolex.value']]

# %%
celltypes_df = celltypes_df.rename({'id': 'model_celltypes_id',
                    'neuroelectro.attr_id': 'electro_id',
                    'description.value': 'description',
                    'neurolex.value': 'neurolex_name'}, axis = 1)

# %% [markdown]
# # regions

# %%
regions_df = pd.json_normalize(regions)

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    display(regions_df.head(3).T)
# Out:
#                                       0                    1  \
# id                               115945               115946
# name                          Neocortex          Hippocampus
# created             2008-10-06T17:06:41  2008-10-06T17:07:19
# ver_number                            1                    1
# ver_date            2008-10-06T17:06:41  2008-10-06T17:07:19
# class_id                            144                  144
# parent.object_name   Vertebrate regions   Vertebrate regions
#
#                                       2
# id                               115947
# name                      Dentate gyrus
# created             2008-10-06T17:07:49
# ver_number                            1
# ver_date            2008-10-06T17:07:49
# class_id                            144
# parent.object_name   Vertebrate regions

# %%
regions_df
# Out:
#         id                             name                  created  \
# 0   115945                        Neocortex      2008-10-06T17:06:41
# 1   115946                      Hippocampus      2008-10-06T17:07:19
# 2   115947                    Dentate gyrus      2008-10-06T17:07:49
# 3   115948                    Turtle cortex      2008-10-06T17:08:14
# 4   115949                 Olfactory cortex      2008-10-06T17:09:18
# 5   115950                   Olfactory bulb      2008-10-06T17:09:51
# 6   115951                         Thalamus      2008-10-06T17:10:15
# 7   115952                    Basal ganglia      2008-10-06T17:10:36
# 8   115953                       Cerebellum      2008-10-06T17:11:05
# 9   115954                Spinal motoneuron      2008-10-06T17:11:40
# 10  115955           Enteric nervous system      2008-10-06T17:12:09
# 11  115956                          Aplysia      2008-10-06T17:12:44
# 12  115957                         Tritonia      2008-10-06T17:13:05
# 13  115958                            Leech      2008-10-06T17:13:22
# 14  115959          Stomatogastric ganglion      2008-10-06T17:13:43
# 15  115960                          Generic      2008-10-06T17:14:15
# 16  115962                          Unknown      2008-10-06T17:32:55
# 17  116370      Hawkmoth Deilephila elpenor      2008-11-13T14:34:39
# 18  116868              Subthalamic Nucleus      2009-01-16T17:17:11
# 19  118308              Superior colliculus      2009-03-23T14:14:31
# 20  118529                           Retina      2009-04-01T16:41:54
# 21  119191                Entorhinal cortex      2009-04-17T14:58:26
# 22  125736            Helix pomatia (snail)      2010-01-28T11:59:31
# 23  127711               Egg-laying circuit      2010-07-08T15:37:55
# 24  138633                         Striatum      2011-04-08T10:55:16
# 25  142628                         Amygdala      2011-11-08T11:09:21
# 26  143145               Auditory brainstem      2011-12-08T16:27:13
# 27  144485                  Auditory cortex      2012-04-26T16:00:45
# 28  144513              Inferior Colliculus      2012-06-04T10:47:05
# 29  147188          Prefrontal cortex (PFC)      2013-01-15T10:26:39
# 30  151437  Lamprey, Spinal cord, Brainstem      2013-10-30T10:59:25
# 31  154751                    Medial Septum  2014-05-23T10:48:55.253
# 32  183076                        Brainstem   2015-07-08T16:33:13.28
# 33  206363                       Drosophila  2016-10-26T13:52:40.763
# 34  227987                            Human  2017-05-19T13:49:14.253
# 35  228597                    Barrel cortex  2017-05-22T11:56:48.737
# 36  228598                            Mouse  2017-05-22T12:01:10.843
# 37  234657                         Goldfish  2017-11-21T10:11:34.763
# 38  239013                          Xenopus  2018-03-05T17:16:34.383
# 39  241764         Turtle vestibular system  2018-05-30T16:07:28.077
# 40  249414    Globus pallidus externa (GPe)   2019-01-12T10:29:50.64
# 41  262706                    Mushroom body  2020-03-11T10:59:15.557
# 42  262707                           Locust  2020-03-11T11:03:26.243
# 43  266649        Optic lobe/Praying Mantis  2020-06-24T10:25:42.567
# 44  266967      Blowfly (Calliphora vicina)   2021-03-14T20:00:15.35
# 45  266968        Honeybee (Apis mellifera)   2021-03-14T20:01:37.25
# 46  266986                    Visual cortex   2021-03-23T06:09:38.49
#
#     ver_number                 ver_date  class_id    parent.object_name
# 0            1      2008-10-06T17:06:41       144    Vertebrate regions
# 1            1      2008-10-06T17:07:19       144    Vertebrate regions
# 2            1      2008-10-06T17:07:49       144    Vertebrate regions
# 3            1      2008-10-06T17:08:14       144    Vertebrate regions
# 4            1      2008-10-06T17:09:18       144    Vertebrate regions
# 5            1      2008-10-06T17:09:51       144    Vertebrate regions
# 6            1      2008-10-06T17:10:15       144    Vertebrate regions
# 7            1      2008-10-06T17:10:36       144    Vertebrate regions
# 8            1      2008-10-06T17:11:05       144    Vertebrate regions
# 9            2      2008-10-06T17:41:01       144    Vertebrate regions
# 10           2  2014-07-21T13:05:33.223       144    Vertebrate regions
# 11           1      2008-10-06T17:12:44       144               Species
# 12           1      2008-10-06T17:13:05       144               Species
# 13           1      2008-10-06T17:13:22       144               Species
# 14           1      2008-10-06T17:13:43       144  Invertebrate regions
# 15           2      2008-10-06T17:28:58       144         Miscellaneous
# 16           1      2008-10-06T17:32:55       144         Miscellaneous
# 17           2  2016-10-10T14:36:21.293       144               Species
# 18           1      2009-01-16T17:17:11       144    Vertebrate regions
# 19           1      2009-03-23T14:14:31       144    Vertebrate regions
# 20           1      2009-04-01T16:41:54       144         Miscellaneous
# 21           1      2009-04-17T14:58:26       144    Vertebrate regions
# 22           1      2010-01-28T11:59:31       144               Species
# 23           2   2016-10-10T14:36:35.59       144         Miscellaneous
# 24           1      2011-04-08T10:55:16       144    Vertebrate regions
# 25           1      2011-11-08T11:09:21       144    Vertebrate regions
# 26           1      2011-12-08T16:27:13       144    Vertebrate regions
# 27           1      2012-04-26T16:00:45       144    Vertebrate regions
# 28           1      2012-06-04T10:47:05       144    Vertebrate regions
# 29           3      2013-01-15T10:27:55       144    Vertebrate regions
# 30           1      2013-10-30T10:59:25       144    Vertebrate regions
# 31           1  2014-05-23T10:48:55.253       144    Vertebrate regions
# 32           1   2015-07-08T16:33:13.28       144    Vertebrate regions
# 33           3   2016-10-26T13:53:42.11       144               Species
# 34           1  2017-05-19T13:49:14.253       144               Species
# 35           2  2017-05-22T11:57:04.313       144    Vertebrate regions
# 36           1  2017-05-22T12:01:10.843       144               Species
# 37           1  2017-11-21T10:11:34.763       144               Species
# 38           1  2018-03-05T17:16:34.383       144               Species
# 39           1  2018-05-30T16:07:28.077       144    Vertebrate regions
# 40           2    2019-01-12T14:30:45.9       144    Vertebrate regions
# 41           2  2020-03-11T15:11:20.543       144  Invertebrate regions
# 42           1  2020-03-11T11:03:26.243       144               Species
# 43           1  2020-06-24T10:25:42.567       144  Invertebrate regions
# 44           1   2021-03-14T20:00:15.35       144               Species
# 45           1   2021-03-14T20:01:37.25       144               Species
# 46           1   2021-03-23T06:09:38.49       144    Vertebrate regions

# %%
regions_df = regions_df.rename(columns = {'name': 'primary_brain_region'})
regions_df['primary_brain_region'] = regions_df['primary_brain_region'].apply(lambda x: x.lower())

# %%
# merge the regions on the neuron_df data set to see if there is overlap
test_merge = pd.merge(neuron_df, regions_df,
        on = 'primary_brain_region',
        validate = 'many_to_one',
        how = 'left',
        indicator = True)

# %%
# they can be merged on the brain region which is helpful
test_merge.query("_merge == 'both'")
# Out:
#         neuron_id            neuron_name     archive  \
# 0               1               cnic_001  Wearne_Hof
# 1              10               cnic_041  Wearne_Hof
# 2             100                   n419      Turner
# 3            1000             DS3_030701     Staiger
# 5          100000  test_set_skeleton_246    Kornfeld
# ...           ...                    ...         ...
# 260073      99995    test_set_skeleton_2    Kornfeld
# 260074      99996  test_set_skeleton_214    Kornfeld
# 260075      99997  test_set_skeleton_227    Kornfeld
# 260076      99998  test_set_skeleton_233    Kornfeld
# 260077      99999  test_set_skeleton_235    Kornfeld
#
#                                                      note age_scale  \
# 0       When originally released, this reconstruction ...      Year
# 1       When originally released, this reconstruction ...      Year
# 2       When originally released, this reconstruction ...     Month
# 3       When originally released, this reconstruction ...       Day
# 5                                                               Day
# ...                                                   ...       ...
# 260073                                                          Day
# 260074                                                          Day
# 260075                                                          Day
# 260076                                                          Day
# 260077                                                          Day
#
#              gender age_classification      species        strain  \
# 0       Male/Female                old       monkey        Rhesus
# 1       Male/Female                old       monkey        Rhesus
# 2       Male/Female              young          rat   Fischer 344
# 3              Male              young          rat        Wistar
# 5              Male              adult  zebra finch  Not reported
# ...             ...                ...          ...           ...
# 260073         Male              adult  zebra finch  Not reported
# 260074         Male              adult  zebra finch  Not reported
# 260075         Male              adult  zebra finch  Not reported
# 260076         Male              adult  zebra finch  Not reported
# 260077         Male              adult  zebra finch  Not reported
#
#           scientific_name  ... fractal_Dim bif_ampl_remote    length  \
# 0          Macaca mulatta  ...     1.01989         50.4610   4911.50
# 1          Macaca mulatta  ...     1.02661         52.7609   3450.30
# 2       rattus norvegicus  ...     1.04104         57.4892  13143.00
# 3       rattus norvegicus  ...     1.04026         57.4939  16972.20
# 5                    None  ...     1.10664         95.8647   1592.93
# ...                   ...  ...         ...             ...       ...
# 260073               None  ...     1.10539         80.5452   1948.35
# 260074               None  ...     1.06018         99.6512   2196.69
# 260075               None  ...     1.07523         96.1616   1813.50
# 260076               None  ...     1.07932         91.0878   2962.11
# 260077               None  ...     1.07201         91.7167   3259.37
#
#               id              created ver_number             ver_date  \
# 0       115945.0  2008-10-06T17:06:41        1.0  2008-10-06T17:06:41
# 1       115945.0  2008-10-06T17:06:41        1.0  2008-10-06T17:06:41
# 2       115946.0  2008-10-06T17:07:19        1.0  2008-10-06T17:07:19
# 3       115945.0  2008-10-06T17:06:41        1.0  2008-10-06T17:06:41
# 5       115952.0  2008-10-06T17:10:36        1.0  2008-10-06T17:10:36
# ...          ...                  ...        ...                  ...
# 260073  115952.0  2008-10-06T17:10:36        1.0  2008-10-06T17:10:36
# 260074  115952.0  2008-10-06T17:10:36        1.0  2008-10-06T17:10:36
# 260075  115952.0  2008-10-06T17:10:36        1.0  2008-10-06T17:10:36
# 260076  115952.0  2008-10-06T17:10:36        1.0  2008-10-06T17:10:36
# 260077  115952.0  2008-10-06T17:10:36        1.0  2008-10-06T17:10:36
#
#        class_id  parent.object_name _merge
# 0         144.0  Vertebrate regions   both
# 1         144.0  Vertebrate regions   both
# 2         144.0  Vertebrate regions   both
# 3         144.0  Vertebrate regions   both
# 5         144.0  Vertebrate regions   both
# ...         ...                 ...    ...
# 260073    144.0  Vertebrate regions   both
# 260074    144.0  Vertebrate regions   both
# 260075    144.0  Vertebrate regions   both
# 260076    144.0  Vertebrate regions   both
# 260077    144.0  Vertebrate regions   both
#
# [181627 rows x 80 columns]

# %%
regions_df = regions_df.rename({'id': 'model_region_id',
                  'parent.object_name': 'parent'}, axis = 1)

# %% [markdown]
# # papers

# %%
papers_df = pd.json_normalize(papers)

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    display(papers_df.head(3).T)
# Out:
#                                                                             0  \
# id                                                                       4161
# name                        Destexhe A, Neubig M, Ulrich D, Huguenard J (1...
# created                                                   2002-03-15T11:18:19
# ver_number                                                                  5
# ver_date                                           2023-05-08T16:49:08.358398
# class_id                                                                 42.0
# title.value                 Dendritic low-threshold calcium currents in th...
# title.attr_id                                                           139.0
# references.value            [{'object_id': 4170, 'object_name': 'Destexhe ...
# references.attr_id                                                      140.0
# authors.value               [{'object_id': 3880, 'object_name': 'Destexhe ...
# authors.attr_id                                                         148.0
# volume.value                                                               18
# volume.attr_id                                                          149.0
# first_page.value                                                         3574
# first_page.attr_id                                                      150.0
# last_page.value                                                            88
# last_page.attr_id                                                       151.0
# pubmed_id.value                                                       9570789
# pubmed_id.attr_id                                                       153.0
# year.value                                                               1998
# year.attr_id                                                            154.0
# month.value                                                               May
# month.attr_id                                                           156.0
# day.value                                                                  15
# day.attr_id                                                             157.0
# journal.value               The Journal of neuroscience : the official jou...
# journal.attr_id                                                         158.0
# missing_references.value                                             all done
# missing_references.attr_id                                              211.0
# type.value                                                                  M
# type.attr_id                                                            337.0
# url.value                    http://www.jneurosci.org/content/18/10/3574.long
# url.attr_id                                                             428.0
# doi.value                                  10.1523/JNEUROSCI.18-10-03574.1998
# doi.attr_id                                                             339.0
# doi.value_lower                            10.1523/jneurosci.18-10-03574.1998
# stated_usage.value                                                        NaN
# stated_usage.attr_id                                                      NaN
# species.value                                                             NaN
# species.attr_id                                                           NaN
# publisher.value                                                           NaN
# publisher.attr_id                                                         NaN
# book_editor.value                                                         NaN
# book_editor.attr_id                                                       NaN
#
#                                                                             1  \
# id                                                                       4036
# name                                       Davison AP, Feng J, Brown D (2000)
# created                                                   2002-03-15T11:06:36
# ver_number                                                                  5
# ver_date                                           2023-05-08T16:49:08.328236
# class_id                                                                 42.0
# title.value                 A reduced compartmental model of the mitral ce...
# title.attr_id                                                           139.0
# references.value            [{'object_id': 4373, 'object_name': 'Bush PC, ...
# references.attr_id                                                      140.0
# authors.value               [{'object_id': 4034, 'object_name': 'Davison A...
# authors.attr_id                                                         148.0
# volume.value                                                               51
# volume.attr_id                                                          149.0
# first_page.value                                                          393
# first_page.attr_id                                                      150.0
# last_page.value                                                             9
# last_page.attr_id                                                       151.0
# pubmed_id.value                                                      10715559
# pubmed_id.attr_id                                                       153.0
# year.value                                                               2000
# year.attr_id                                                            154.0
# month.value                                                               Mar
# month.attr_id                                                           156.0
# day.value                                                                  15
# day.attr_id                                                             157.0
# journal.value                                         Brain research bulletin
# journal.attr_id                                                         158.0
# missing_references.value                                             all done
# missing_references.attr_id                                              211.0
# type.value                                                                  M
# type.attr_id                                                            337.0
# url.value                                                                 NaN
# url.attr_id                                                               NaN
# doi.value                                       10.1016/s0361-9230(99)00256-7
# doi.attr_id                                                             339.0
# doi.value_lower                                 10.1016/s0361-9230(99)00256-7
# stated_usage.value                                                        NaN
# stated_usage.attr_id                                                      NaN
# species.value                                                             NaN
# species.attr_id                                                           NaN
# publisher.value                                                           NaN
# publisher.attr_id                                                         NaN
# book_editor.value                                                         NaN
# book_editor.attr_id                                                       NaN
#
#                                                                             2
# id                                                                       4252
# name                                           Mainen ZF, Sejnowski TJ (1996)
# created                                                   2002-03-15T11:23:56
# ver_number                                                                  5
# ver_date                                           2023-05-08T16:49:10.952346
# class_id                                                                 42.0
# title.value                 Influence of dendritic structure on firing pat...
# title.attr_id                                                           139.0
# references.value            [{'object_id': 4290, 'object_name': 'Mainen ZF...
# references.attr_id                                                      140.0
# authors.value               [{'object_id': 4251, 'object_name': 'Mainen ZF...
# authors.attr_id                                                         148.0
# volume.value                                                              382
# volume.attr_id                                                          149.0
# first_page.value                                                          363
# first_page.attr_id                                                      150.0
# last_page.value                                                             6
# last_page.attr_id                                                       151.0
# pubmed_id.value                                                       8684467
# pubmed_id.attr_id                                                       153.0
# year.value                                                               1996
# year.attr_id                                                            154.0
# month.value                                                               Jul
# month.attr_id                                                           156.0
# day.value                                                                  25
# day.attr_id                                                             157.0
# journal.value                                                          Nature
# journal.attr_id                                                         158.0
# missing_references.value                                             all done
# missing_references.attr_id                                              211.0
# type.value                                                                  M
# type.attr_id                                                            337.0
# url.value                                                                 NaN
# url.attr_id                                                               NaN
# doi.value                                                    10.1038/382363a0
# doi.attr_id                                                             339.0
# doi.value_lower                                              10.1038/382363a0
# stated_usage.value                                                        NaN
# stated_usage.attr_id                                                      NaN
# species.value                                                             NaN
# species.attr_id                                                           NaN
# publisher.value                                                           NaN
# publisher.attr_id                                                         NaN
# book_editor.value                                                         NaN
# book_editor.attr_id                                                       NaN

# %%
papers_df = papers_df[['id', 'name', 'created', 'title.value', 'pubmed_id.value', 
                       'year.value', 'journal.value', 'doi.value', 'doi.value_lower']]

# %%
papers_df = papers_df.rename({'id': 'model_paper_id',
                 'title.value': 'title',
                 'pubmed_id.value': 'pubmed',
                 'year.value': 'year',
                 'journal.value': 'journal',
                 'doi.value': 'doi',
                 'doi.value_lower': 'doi_lower'}, axis = 1)

# %%
# check if the doi match 
test_merge = pd.merge(neuron_doi, papers_df,
        left_on = 'reference_doi',
        right_on = 'doi',
        how = 'outer',
        indicator = True)

# %%
# 2388 rows match on the doi
test_merge.query("_merge == 'both'")
# Out:
#         neuron_id                   reference_doi  model_paper_id  \
# 2102      10033.0           10.1152/jn.00891.2012        155603.0
# 2103      10034.0           10.1152/jn.00891.2012        155603.0
# 2104      10035.0           10.1152/jn.00891.2012        155603.0
# 2105      10036.0           10.1152/jn.00891.2012        155603.0
# 2347     101622.0    10.1371/journal.pone.0200626        248831.0
# ...           ...                             ...             ...
# 264702     9422.0  10.1523/JNEUROSCI.2581-12.2012        144558.0
# 264703     9423.0  10.1523/JNEUROSCI.2581-12.2012        144558.0
# 264704     9424.0  10.1523/JNEUROSCI.2581-12.2012        144558.0
# 264705     9425.0  10.1523/JNEUROSCI.2581-12.2012        144558.0
# 264706     9426.0  10.1523/JNEUROSCI.2581-12.2012        144558.0
#
#                                                      name  \
# 2102    Yu J, Proddutur A, Elgammal FS, Ito T, Santhak...
# 2103    Yu J, Proddutur A, Elgammal FS, Ito T, Santhak...
# 2104    Yu J, Proddutur A, Elgammal FS, Ito T, Santhak...
# 2105    Yu J, Proddutur A, Elgammal FS, Ito T, Santhak...
# 2347                           Goodliffe JW et al. (2018)
# ...                                                   ...
# 264702                          Amatrudo JM et al. (2012)
# 264703                          Amatrudo JM et al. (2012)
# 264704                          Amatrudo JM et al. (2012)
# 264705                          Amatrudo JM et al. (2012)
# 264706                          Amatrudo JM et al. (2012)
#
#                         created  \
# 2102        2014-06-30T09:13:37
# 2103        2014-06-30T09:13:37
# 2104        2014-06-30T09:13:37
# 2105        2014-06-30T09:13:37
# 2347    2019-01-08T11:28:07.057
# ...                         ...
# 264702      2012-07-06T11:26:38
# 264703      2012-07-06T11:26:38
# 264704      2012-07-06T11:26:38
# 264705      2012-07-06T11:26:38
# 264706      2012-07-06T11:26:38
#
#                                                     title    pubmed  year  \
# 2102    Status epilepticus enhances tonic GABA current...  23324316  2013
# 2103    Status epilepticus enhances tonic GABA current...  23324316  2013
# 2104    Status epilepticus enhances tonic GABA current...  23324316  2013
# 2105    Status epilepticus enhances tonic GABA current...  23324316  2013
# 2347    Differential changes to D1 and D2 medium spiny...  30118496  2018
# ...                                                   ...       ...   ...
# 264702  Influence of highly distinctive structural pro...  23035077  2012
# 264703  Influence of highly distinctive structural pro...  23035077  2012
# 264704  Influence of highly distinctive structural pro...  23035077  2012
# 264705  Influence of highly distinctive structural pro...  23035077  2012
# 264706  Influence of highly distinctive structural pro...  23035077  2012
#
#                                                   journal  \
# 2102                           Journal of neurophysiology
# 2103                           Journal of neurophysiology
# 2104                           Journal of neurophysiology
# 2105                           Journal of neurophysiology
# 2347                                             PloS one
# ...                                                   ...
# 264702  The Journal of neuroscience : the official jou...
# 264703  The Journal of neuroscience : the official jou...
# 264704  The Journal of neuroscience : the official jou...
# 264705  The Journal of neuroscience : the official jou...
# 264706  The Journal of neuroscience : the official jou...
#
#                                    doi                       doi_lower _merge
# 2102             10.1152/jn.00891.2012           10.1152/jn.00891.2012   both
# 2103             10.1152/jn.00891.2012           10.1152/jn.00891.2012   both
# 2104             10.1152/jn.00891.2012           10.1152/jn.00891.2012   both
# 2105             10.1152/jn.00891.2012           10.1152/jn.00891.2012   both
# 2347      10.1371/journal.pone.0200626    10.1371/journal.pone.0200626   both
# ...                                ...                             ...    ...
# 264702  10.1523/JNEUROSCI.2581-12.2012  10.1523/jneurosci.2581-12.2012   both
# 264703  10.1523/JNEUROSCI.2581-12.2012  10.1523/jneurosci.2581-12.2012   both
# 264704  10.1523/JNEUROSCI.2581-12.2012  10.1523/jneurosci.2581-12.2012   both
# 264705  10.1523/JNEUROSCI.2581-12.2012  10.1523/jneurosci.2581-12.2012   both
# 264706  10.1523/JNEUROSCI.2581-12.2012  10.1523/jneurosci.2581-12.2012   both
#
# [2388 rows x 12 columns]

# %%
# checking on pubmed_id
test_merge = pd.merge(neuron_pmid, papers_df,
        left_on = 'reference_pmid',
        right_on = 'pubmed',
        how = 'outer',
        indicator = True)
test_merge.query("_merge == 'both'")
# 671 rows match
# Out:
#         neuron_id reference_pmid  model_paper_id  \
# 2102      10033.0       23324316        155603.0
# 2103      10034.0       23324316        155603.0
# 2104      10035.0       23324316        155603.0
# 2105      10036.0       23324316        155603.0
# 2347     101622.0       30118496        248831.0
# ...           ...            ...             ...
# 262947     9422.0       23035077        144558.0
# 262948     9423.0       23035077        144558.0
# 262949     9424.0       23035077        144558.0
# 262950     9425.0       23035077        144558.0
# 262951     9426.0       23035077        144558.0
#
#                                                      name  \
# 2102    Yu J, Proddutur A, Elgammal FS, Ito T, Santhak...
# 2103    Yu J, Proddutur A, Elgammal FS, Ito T, Santhak...
# 2104    Yu J, Proddutur A, Elgammal FS, Ito T, Santhak...
# 2105    Yu J, Proddutur A, Elgammal FS, Ito T, Santhak...
# 2347                           Goodliffe JW et al. (2018)
# ...                                                   ...
# 262947                          Amatrudo JM et al. (2012)
# 262948                          Amatrudo JM et al. (2012)
# 262949                          Amatrudo JM et al. (2012)
# 262950                          Amatrudo JM et al. (2012)
# 262951                          Amatrudo JM et al. (2012)
#
#                         created  \
# 2102        2014-06-30T09:13:37
# 2103        2014-06-30T09:13:37
# 2104        2014-06-30T09:13:37
# 2105        2014-06-30T09:13:37
# 2347    2019-01-08T11:28:07.057
# ...                         ...
# 262947      2012-07-06T11:26:38
# 262948      2012-07-06T11:26:38
# 262949      2012-07-06T11:26:38
# 262950      2012-07-06T11:26:38
# 262951      2012-07-06T11:26:38
#
#                                                     title    pubmed  year  \
# 2102    Status epilepticus enhances tonic GABA current...  23324316  2013
# 2103    Status epilepticus enhances tonic GABA current...  23324316  2013
# 2104    Status epilepticus enhances tonic GABA current...  23324316  2013
# 2105    Status epilepticus enhances tonic GABA current...  23324316  2013
# 2347    Differential changes to D1 and D2 medium spiny...  30118496  2018
# ...                                                   ...       ...   ...
# 262947  Influence of highly distinctive structural pro...  23035077  2012
# 262948  Influence of highly distinctive structural pro...  23035077  2012
# 262949  Influence of highly distinctive structural pro...  23035077  2012
# 262950  Influence of highly distinctive structural pro...  23035077  2012
# 262951  Influence of highly distinctive structural pro...  23035077  2012
#
#                                                   journal  \
# 2102                           Journal of neurophysiology
# 2103                           Journal of neurophysiology
# 2104                           Journal of neurophysiology
# 2105                           Journal of neurophysiology
# 2347                                             PloS one
# ...                                                   ...
# 262947  The Journal of neuroscience : the official jou...
# 262948  The Journal of neuroscience : the official jou...
# 262949  The Journal of neuroscience : the official jou...
# 262950  The Journal of neuroscience : the official jou...
# 262951  The Journal of neuroscience : the official jou...
#
#                                    doi                       doi_lower _merge
# 2102             10.1152/jn.00891.2012           10.1152/jn.00891.2012   both
# 2103             10.1152/jn.00891.2012           10.1152/jn.00891.2012   both
# 2104             10.1152/jn.00891.2012           10.1152/jn.00891.2012   both
# 2105             10.1152/jn.00891.2012           10.1152/jn.00891.2012   both
# 2347      10.1371/journal.pone.0200626    10.1371/journal.pone.0200626   both
# ...                                ...                             ...    ...
# 262947  10.1523/JNEUROSCI.2581-12.2012  10.1523/jneurosci.2581-12.2012   both
# 262948  10.1523/JNEUROSCI.2581-12.2012  10.1523/jneurosci.2581-12.2012   both
# 262949  10.1523/JNEUROSCI.2581-12.2012  10.1523/jneurosci.2581-12.2012   both
# 262950  10.1523/JNEUROSCI.2581-12.2012  10.1523/jneurosci.2581-12.2012   both
# 262951  10.1523/JNEUROSCI.2581-12.2012  10.1523/jneurosci.2581-12.2012   both
#
# [671 rows x 12 columns]

# %% [markdown]
# ### modelconcepts

# %%
f = open('Data/modeldb_modelconcepts.json', 'r')
modelconcepts = json.loads(f.read())
f.close()

# %%
modelconcepts_df = pd.json_normalize(modelconcepts)

# %%
modelconcepts_df = modelconcepts_df[['id', 'name', 'description.value']]
modelconcepts_df.rename({'id': 'model_concept_id',
                        'description.value': 'description'}, axis = 1, inplace = True)

# %%
modelconcepts_df
# Out:
#      model_concept_id                                  name  \
# 0                3541           Action Potential Initiation
# 1                3542                   Pattern Recognition
# 2                3543                     Activity Patterns
# 3                3629           Dendritic Action Potentials
# 4                3630                              Bursting
# ..                ...                                   ...
# 209            267152  Dynamic extracellular concentrations
# 210            267153                               Ramping
# 211            267345  Effective Optokinetic Response (OKR)
# 212            267348           Eyeblink Conditioning (EBC)
# 213            267410          Synaptic Tagging and Capture
#
#                                            description
# 0    The model is used to investigate factors affec...
# 1    The model is able to recognize spatial and/or ...
# 2    Spatial and/or temporal patterns of spiking ac...
# 3    The model is used to investigate action potent...
# 4    The model is used to investigate mechanisms of...
# ..                                                 ...
# 209                                                NaN
# 210                                                NaN
# 211                                                NaN
# 212                                                NaN
# 213                                                NaN
#
# [214 rows x 3 columns]

# %% [markdown]
# ### modeltypes

# %%
f = open('Data/modeldb_modeltypes.json', 'r')
modeltypes = json.loads(f.read())
f.close()

# %%
modeltypes_df = pd.json_normalize(modeltypes)

# %%
modeltypes_df = modeltypes_df[['id', 'name']]

# %%
modeltypes_df.rename({'id': 'model_type_id'}, axis = 1, inplace = True)

# %% [markdown]
# ### receptors

# %%
f = open('Data/modeldb_receptors.json', 'r')
receptors = json.loads(f.read())
f.close()

# %%
receptors = pd.json_normalize(receptors)

# %%
receptors.head(3).T
# Out:
#                                                                          0  \
# id                                                                     178
# name                                                             Nicotinic
# created                                                2002-04-02T00:00:02
# ver_number                                                               1
# ver_date                                               2002-04-02T00:00:02
# class_id                                                                 9
# parent_receptor.value    [{'object_id': 218, 'object_name': 'Cholinergi...
# parent_receptor.attr_id                                               66.0
#
#                                                                          1  \
# id                                                                     179
# name                                                                    M1
# created                                                2002-04-02T00:00:02
# ver_number                                                               1
# ver_date                                               2002-04-02T00:00:02
# class_id                                                                 9
# parent_receptor.value    [{'object_id': 204, 'object_name': 'Muscarinic'}]
# parent_receptor.attr_id                                               66.0
#
#                                                                          2
# id                                                                     180
# name                                                                    M3
# created                                                2002-04-02T00:00:02
# ver_number                                                               1
# ver_date                                               2002-04-02T00:00:02
# class_id                                                                 9
# parent_receptor.value    [{'object_id': 204, 'object_name': 'Muscarinic'}]
# parent_receptor.attr_id                                               66.0

# %%
parent_receptor_df = normalize_json_objects(receptors, 'parent_receptor.value', ['parent_id', 'parent_receptor_name', 'model_receptor_id'])

# %%
receptors.rename({'id': 'model_receptor_id'}, axis = 1, inplace = True)

# %%
parent_receptor_types_df = parent_receptor_df[['parent_id', 'parent_receptor_name']].drop_duplicates(['parent_id', 'parent_receptor_name'])

# %%
parent_receptor_types_df
# Out:
#     parent_id   parent_receptor_name
# 0         218  Cholinergic Receptors
# 1         204             Muscarinic
# 6         207                  mGluR
# 14        215             Adrenergic
# 15        192                  Alpha
# 18        223  Dopaminergic Receptor
# 20        216              Serotonin
# 23        217              Histamine
# 24        213                   Gaba
# 27        212              Glutamate
# 32        219   Amino Acid Receptors
# 34        211    Monoamine Receptors
# 37        220      Sensory Receptors
# 41       2372      Gaseous Receptors
# 42       2388      Peptide Receptors
# 44       2391          Ion Receptors

# %% [markdown]
# ### Transmitters

# %%
f = open('Data/modeldb_transmitters.json', 'r')
transmitters = json.loads(f.read())
f.close()

# %%
transmitters_df = pd.json_normalize(transmitters)

# %%
transmitters_df.head(3).T
# Out:
#                                              0  \
# id                                         209
# name                             Acetylcholine
# created                    2004-01-08T13:19:48
# ver_number                                   1
# ver_date                   2004-01-08T13:19:48
# class_id                                     7
# Parent_Neurotrans.value                    NaN
# Parent_Neurotrans.attr_id                  NaN
# color.value                                NaN
# color.attr_id                              NaN
#
#                                                                            1  \
# id                                                                       214
# name                                                                 Glycine
# created                                                  2002-04-02T00:00:02
# ver_number                                                                 1
# ver_date                                                 2002-04-02T00:00:02
# class_id                                                                   7
# Parent_Neurotrans.value    [{'object_id': 231, 'object_name': 'Amino Acid...
# Parent_Neurotrans.attr_id                                               67.0
# color.value                                                              NaN
# color.attr_id                                                            NaN
#
#                                                                            2
# id                                                                       224
# name                                                                Dopamine
# created                                                  2001-02-15T11:38:07
# ver_number                                                                 1
# ver_date                                                 2001-02-15T11:38:07
# class_id                                                                   7
# Parent_Neurotrans.value    [{'object_id': 234, 'object_name': 'Monoamines'}]
# Parent_Neurotrans.attr_id                                               67.0
# color.value                                                              NaN
# color.attr_id                                                            NaN

# %%
model_neurotrans_classes = normalize_json_objects(transmitters_df, 'Parent_Neurotrans.value', ['neurotrans_class_id', 'neurotrans_class_name', 'model_id'])

# %%
neurotrans_classes = model_neurotrans_classes[['neurotrans_class_id', 'neurotrans_class_name']].drop_duplicates(['neurotrans_class_id', 'neurotrans_class_name'])

# %%
neurotrans_classes
# Out:
#    neurotrans_class_id neurotrans_class_name
# 0                  231           Amino Acids
# 1                  234            Monoamines
# 2                  236                  Ions
# 3                  237                 Gases
# 5                  235              Peptides

# %% [markdown]
# # Looking Through Tables and Inserting to Data Base

# %%
POSTGRES_PASSWORD = os.getenv('POSTGRES_PASSWORD')
import psycopg2
from sqlalchemy import create_engine

# %%
dbserver = psycopg2.connect(
    host = 'postgres',
    user = 'postgres',
    password = POSTGRES_PASSWORD,
    port = 5432
)
dbserver.autocommit = True

# %%
cursor = dbserver.cursor()

# %%
try:
    cursor.execute('CREATE DATABASE neurodash')
except:
    cursor.execute('DROP DATABASE neurodash')
    cursor.execute('CREATE DATABASE neurodash')

# %%
engine = create_engine('postgresql+psycopg2://{user}:{password}@{host}:{port}/{db}'.format(
    user = 'postgres',
    password = POSTGRES_PASSWORD,
    host = 'postgres',
    port = 5432,
    db = 'neurodash'
))

# %% [markdown]
# ### Neuron

# %%
neuron_df.drop(['soma_surface'], axis = 1, inplace = True)

# %%
neuron_df.columns = neuron_df.columns.str.lower()

# %%
neuron_df.head(2)
# Out:
#    neuron_id neuron_name     archive  \
# 0          1    cnic_001  Wearne_Hof
# 1         10    cnic_041  Wearne_Hof
#
#                                                 note age_scale       gender  \
# 0  When originally released, this reconstruction ...      Year  Male/Female
# 1  When originally released, this reconstruction ...      Year  Male/Female
#
#   age_classification species  strain scientific_name  ... pathdistance  \
# 0                old  monkey  Rhesus  Macaca mulatta  ...      253.921
# 1                old  monkey  Rhesus  Macaca mulatta  ...      264.030
#
#   branch_order contraction fragmentation partition_asymmetry pk_classic  \
# 0          8.0    0.934755        1274.0            0.413619    1.52521
# 1          7.0    0.909303        1038.0            0.410981    1.99859
#
#   bif_ampl_local fractal_dim bif_ampl_remote  length
# 0        33.3799     1.01989         50.4610  4911.5
# 1        66.5523     1.02661         52.7609  3450.3
#
# [2 rows x 72 columns]

# %%
print(neuron_df.shape[0])
neuron_df.to_sql('neuron', con=engine, index=False, chunksize=100, if_exists = 'replace')
# Out:
# 260078
# 260078

# %%
neuron_cell_type.head(2)
# Out:
#    neuron_id         cell_type
# 0          1  Local projecting
# 0          1         pyramidal

# %%
print(neuron_cell_type.shape[0])
neuron_cell_type.to_sql('neuron_cell_type', con=engine, index=False, 
                        chunksize=100, if_exists = 'replace')
# Out:
# 664383
# 664383

# %%
neuron_exp_condition.head(2)
# Out:
#    neuron_id experiment_condition
# 0          1              Control
# 1         10              Control

# %%
print(neuron_exp_condition.shape[0])
neuron_exp_condition.to_sql('neuron_exp_condition', con=engine, index=False, 
                        chunksize=100, if_exists = 'replace')
# Out:
# 261100
# 261100

# %%
neuron_pmid.head(2)
# Out:
#    neuron_id reference_pmid
# 0          1       12204204
# 0          1       12902394

# %%
print(neuron_pmid.shape[0])
neuron_pmid.to_sql('neuron_pmid', con=engine, index=False, 
                        chunksize=100, if_exists = 'replace')
# Out:
# 266069
# 266069

# %%
neuron_doi.head(2)
# Out:
#    neuron_id                  reference_doi
# 0          1  10.1016/S0306-4522(02)00305-6
# 0          1        10.1093/cercor/13.9.950

# %%
print(neuron_doi.shape[0])
neuron_doi.to_sql('neuron_doi', con=engine, index=False, 
                        chunksize=100, if_exists = 'replace')
# Out:
# 266069
# 266069

# %% [markdown]
# ### Electro

# %%
electro.columns = electro.columns.str.lower()
electro.head(2)
# Out:
#    electro_id      pmid  tableid                 neuronname  \
# 0         150  24108800  35984.0      Neocortex basket cell
# 1         149  24108800  35984.0  Neocortex Martinotti cell
#
#                                       neuronlongname  \
# 0   medial prefrontal cortex fast spiking interne...
# 1  medial prefrontal cortex low-threshold spiking...
#
#                                       neuronprefname brainregion  \
# 0   medial prefrontal cortex fast spiking interne...   isocortex
# 1  medial prefrontal cortex low-threshold spiking...   isocortex
#
#    metadatacurated species        strain  ... sahpamprest sahpamprest_raw  \
# 0             True    rats  Rats, Wistar  ...         NaN             NaN
# 1             True    rats  Rats, Wistar  ...         NaN             NaN
#
#   sahpamprest_err  sahpamprest_n  sahpamprest_sd  fahpamprest  \
# 0             NaN            NaN             NaN          NaN
# 1             NaN            NaN             NaN          NaN
#
#    fahpamprest_raw fahpamprest_err  fahpamprest_n  fahpamprest_sd
# 0              NaN             NaN            NaN             NaN
# 1              NaN             NaN            NaN             NaN
#
# [2 rows x 327 columns]

# %%
print(electro.shape[0])
electro.to_sql('electro', con=engine, index=False, 
                        chunksize=100, if_exists = 'replace')
# Out:
# 1515
# 1515

# %%
electro_pub.columns = electro_pub.columns.str.lower()
electro_pub['pmid'] = electro_pub['pmid'].astype('object')
electro_pub.head(2)
# Out:
#        pmid  articleid                                              title  \
# 0  24108800      88449  Cell type-specific effects of adenosine on cor...
# 4  24323499      88469  Age-related changes to layer 3 pyramidal cells...
#
#    pubyear   lastauthor
# 0     2015  Feldmeyer D
# 4     2015     Peters A

# %%
print(electro_pub.shape[0])
electro_pub.to_sql('electro_pub', con=engine, index=False, 
                        chunksize=100, if_exists = 'replace')
# Out:
# 749
# 749

# %% [markdown]
# ### Models

# %%
models_df.rename({'id': 'model_id'}, axis = 1, inplace = True)
models_df.head(2)
# Out:
#    model_id                                               name  \
# 0       279  Low Threshold Calcium Currents in TC cells (De...
# 1      2487         Olfactory Mitral Cell (Davison et al 2000)
#
#                created  ver_number               ver_date  class_id gitrepo
# 0  2001-01-01T00:00:00          24    2015-01-02T22:01:45        19    True
# 1  2001-04-05T22:35:35          14  2022-05-27T18:13:12.8        19   False

# %%
print(models_df.shape[0])
models_df.to_sql('models', con=engine, index=False, 
                        chunksize=100, if_exists = 'replace')
# Out:
# 1836
# 1836

# %%
currents = model_currents_df[['model_current_id', 'model_current_name']].drop_duplicates(['model_current_id', 'model_current_name'])

# %%
currents.head(2)
# Out:
#    model_current_id model_current_name
# 0               242             I Na,t
# 1               245  I T low threshold

# %%
print(currents.shape[0])
currents.to_sql('model_currents', con=engine, index=False, 
                        chunksize=100, if_exists = 'replace')
# Out:
# 64
# 64

# %%
model_currents_df.drop(['model_current_name'], axis = 1, inplace = True)
model_currents_df.head(2)
# Out:
#    model_current_id  model_id
# 0               242       279
# 1               245       279

# %%
print(model_currents_df.shape[0])
model_currents_df.to_sql('model_to_current', con=engine, index=False, 
                        chunksize=100, if_exists = 'replace')
# Out:
# 4734
# 4734

# %%
model_to_celltypes = model_neurons_df[['model_id', 'model_neuron_ids']].rename({'model_neuron_ids': 'model_celltypes_id'}, axis = 1)
model_to_celltypes.head(2)
# Out:
#    model_id  model_celltypes_id
# 0       279                 262
# 1      2487                 267

# %%
print(model_to_celltypes.shape[0])
model_to_celltypes.to_sql('model_to_celltypes', con=engine, index=False, 
                        chunksize=100, if_exists = 'replace')
# Out:
# 2112
# 2112

# %%
celltypes_df.head(2)
# Out:
#    model_celltypes_id                                name  electro_id  \
# 0                 257      Dentate gyrus granule GLU cell       507.0
# 1                 258  Hippocampus CA1 pyramidal GLU cell       507.0
#
#                                          description  \
# 0  The principal neuron of the fascia dentata of ...
# 1  The principal neuron of region CA1 of the hipp...
#
#                     neurolex_name
# 0                             NaN
# 1  Hippocampus_CA1_pyramidal_cell

# %%
print(celltypes_df.shape[0])
celltypes_df.to_sql('model_celltypes', con=engine, index=False, 
                        chunksize=100, if_exists = 'replace')
# Out:
# 278
# 278

# %%
model_types_df.drop(['model_type_name'], axis = 1, inplace = True)
model_types_df.head(2)
# Out:
#    model_type_id  model_id
# 0           3537       279
# 1           3537      2487

# %%
print(model_types_df.shape[0])
model_types_df.to_sql('model_to_types', con=engine, index=False, 
                        chunksize=100, if_exists = 'replace')
# Out:
# 2157
# 2157

# %%
modeltypes_df.head(2)
# Out:
#    model_type_id                                         name
# 0           3536                            Realistic Network
# 1           3537  Neuron or other electrically excitable cell

# %%
print(modeltypes_df.shape[0])
modeltypes_df.to_sql('model_types', con=engine, index=False, 
                        chunksize=100, if_exists = 'replace')
# Out:
# 21
# 21

# %%
#receptors.head(2)

# %%
#print(receptors.shape[0])
#receptors.to_sql('model_types', con=engine, index=False, 
                        #chunksize=100, if_exists = 'replace')

# %%
#parent_receptor_types_df.head(2)

# %%
model_concepts_df.rename({'model_concept_ids': 'model_concept_id'}, axis = 1,
                        inplace = True)
model_to_concept = model_concepts_df[['model_id', 'model_concept_id']]
model_to_concept.head(2)
# Out:
#    model_id  model_concept_id
# 0       279              3629
# 1       279              3630

# %%
print(model_to_concept.shape[0])
model_to_concept.to_sql('model_to_concept', con=engine, index=False, 
                        chunksize=100, if_exists = 'replace')
# Out:
# 5352
# 5352

# %%
modelconcepts_df.head(2)
# Out:
#    model_concept_id                         name  \
# 0              3541  Action Potential Initiation
# 1              3542          Pattern Recognition
#
#                                          description
# 0  The model is used to investigate factors affec...
# 1  The model is able to recognize spatial and/or ...

# %%
print(modelconcepts_df.shape[0])
modelconcepts_df.to_sql('model_concepts', con=engine, index=False, 
                        chunksize=100, if_exists = 'replace')
# Out:
# 214
# 214

# %%
# don't have the model applications data from API
# model_applications_df.head(2)

# %%
model_to_paper = model_paper_df[['model_id', 'model_paper_id']]
model_to_paper.head(2)
# Out:
#    model_id  model_paper_id
# 0       279            4161
# 1      2487            4036

# %%
print(model_to_paper.shape[0])
model_to_paper.to_sql('model_to_papers', con=engine, index=False, 
                        chunksize=100, if_exists = 'replace')
# Out:
# 2100
# 2100

# %%
papers_df.head(2)
# Out:
#    model_paper_id                                               name  \
# 0            4161  Destexhe A, Neubig M, Ulrich D, Huguenard J (1...
# 1            4036                 Davison AP, Feng J, Brown D (2000)
#
#                created                                              title  \
# 0  2002-03-15T11:18:19  Dendritic low-threshold calcium currents in th...
# 1  2002-03-15T11:06:36  A reduced compartmental model of the mitral ce...
#
#      pubmed  year                                            journal  \
# 0   9570789  1998  The Journal of neuroscience : the official jou...
# 1  10715559  2000                            Brain research bulletin
#
#                                   doi                           doi_lower
# 0  10.1523/JNEUROSCI.18-10-03574.1998  10.1523/jneurosci.18-10-03574.1998
# 1       10.1016/s0361-9230(99)00256-7       10.1016/s0361-9230(99)00256-7

# %%
print(papers_df.shape[0])
papers_df.to_sql('model_papers', con=engine, index=False, 
                        chunksize=100, if_exists = 'replace')
# Out:
# 1817
# 1817

# %%
# not sure I need this, don't have run protocols from api
# model_runprotocols_df.head(2)

# %%
model_implemented = model_implemented_df[['model_implemented_id', 'model_implemented_name']].drop_duplicates()
model_implemented.head(2)
# Out:
#    model_implemented_id                             model_implemented_name
# 0                 33744      Destexhe, Alain [Destexhe at iaf.cnrs-gif.fr]
# 1                 33739  Davison, Andrew [Andrew.Davison at iaf.cnrs-gi...

# %%
print(model_implemented.shape[0])
model_implemented.to_sql('model_implemented', con=engine, index=False, 
                        chunksize=100, if_exists = 'replace')
# Out:
# 1030
# 1030

# %%
model_implemented_df = model_implemented_df[['model_id', 'model_implemented_id']]

# %%
model_implemented_df.head(2)
# Out:
#    model_id  model_implemented_id
# 0       279                 33744
# 1      2487                 33739

# %%
print(model_implemented_df.shape[0])
model_implemented_df.to_sql('model_to_implemented', con=engine, index=False, 
                        chunksize=100, if_exists = 'replace')
# Out:
# 1972
# 1972

# %%
model_views_df.head(2)
# Out:
#                              model_views_name  model_id
# 0  Burst behavior in single-compartment model       279
# 1       Burst behavior in 3-compartment model       279

# %%
print(model_views_df.shape[0])
model_views_df.to_sql('model_views', con=engine, index=False, 
                        chunksize=100, if_exists = 'replace')
# Out:
# 594
# 594

# %%
model_to_region = model_region_df[['model_id', 'model_region_id']]
model_to_region.head(2)
# Out:
#    model_id  model_region_id
# 0      2730           115950
# 1      2798           115949

# %%
print(model_to_region.shape[0])
model_to_region.to_sql('model_to_region', con=engine, index=False, 
                        chunksize=100, if_exists = 'replace')
# Out:
# 933
# 933

# %%
regions_df.rename({'region_id': 'model_region_id'}, axis = 1, inplace = True)
regions_df.head(2)
# Out:
#    model_region_id primary_brain_region              created  ver_number  \
# 0           115945            neocortex  2008-10-06T17:06:41           1
# 1           115946          hippocampus  2008-10-06T17:07:19           1
#
#               ver_date  class_id              parent
# 0  2008-10-06T17:06:41       144  Vertebrate regions
# 1  2008-10-06T17:07:19       144  Vertebrate regions

# %%
print(regions_df.shape[0])
regions_df.to_sql('model_regions', con=engine, index=False, 
                        chunksize=100, if_exists = 'replace')
# Out:
# 47
# 47

# %%
model_to_transmitter = model_transmitter_df[['model_id', 'model_transmitter_id']]
model_to_transmitter.head(2)
# Out:
#    model_id  model_transmitter_id
# 0      2730                   232
# 1      2730                   233

# %%
print(model_to_transmitter.shape[0])
model_to_transmitter.to_sql('model_to_transmitter', con=engine, index=False, 
                        chunksize=100, if_exists = 'replace')
# Out:
# 677
# 677

# %%
transmitters_df.rename({'id':'model_transmitter_id',
                       'Parent_Neurotrans.attr_id': 'neurotrans_class_id'}, axis = 1, inplace = True)
transmitters_df.head(2)
# Out:
#    model_transmitter_id           name              created  ver_number  \
# 0                   209  Acetylcholine  2004-01-08T13:19:48           1
# 1                   214        Glycine  2002-04-02T00:00:02           1
#
#               ver_date  class_id  \
# 0  2004-01-08T13:19:48         7
# 1  2002-04-02T00:00:02         7
#
#                              Parent_Neurotrans.value  neurotrans_class_id  \
# 0                                                NaN                  NaN
# 1  [{'object_id': 231, 'object_name': 'Amino Acid...                 67.0
#
#   color.value  color.attr_id
# 0         NaN            NaN
# 1         NaN            NaN

# %%
model_transmitters = transmitters_df.drop(['Parent_Neurotrans.value', 'color.value', 'color.attr_id'], axis = 1)
model_transmitters.rename({'neutrans_class_id': 'neurotrans_class_id'}, axis = 1, inplace = True)
model_transmitters.head(2)
# Out:
#    model_transmitter_id           name              created  ver_number  \
# 0                   209  Acetylcholine  2004-01-08T13:19:48           1
# 1                   214        Glycine  2002-04-02T00:00:02           1
#
#               ver_date  class_id  neurotrans_class_id
# 0  2004-01-08T13:19:48         7                  NaN
# 1  2002-04-02T00:00:02         7                 67.0

# %%
print(model_transmitters.shape[0])
model_transmitters.to_sql('model_transmitters', con=engine, index=False, 
                        chunksize=100, if_exists = 'replace')
# Out:
# 25
# 25

# %%
neurotrans_classes.head(2)
# Out:
#    neurotrans_class_id neurotrans_class_name
# 0                  231           Amino Acids
# 1                  234            Monoamines

# %%
print(neurotrans_classes.shape[0])
neurotrans_classes.to_sql('neurotrans_classes', con=engine, index=False, 
                        chunksize=100, if_exists = 'replace')
# Out:
# 5
# 5

# %%
model_species_df.head(2)
# Out:
#    model_species_id model_species_name  model_id
# 0            114272  Hirudinea (leech)     19698
# 1            249921            Aplysia     34168

# %%
model_species = model_species_df[['model_species_id', 'model_species_name']].drop_duplicates(['model_species_id', 'model_species_name'])
model_species.head(2)
# Out:
#    model_species_id model_species_name
# 0            114272  Hirudinea (leech)
# 1            249921            Aplysia

# %%
print(model_species.shape[0])
model_species.to_sql('model_species', con=engine, index=False, 
                        chunksize=100, if_exists = 'replace')
# Out:
# 12
# 12

# %%
model_to_species = model_species_df[['model_id', 'model_species_id']]
model_to_species.head(2)
# Out:
#    model_id  model_species_id
# 0     19698            114272
# 1     34168            249921

# %%
print(model_to_species.shape[0])
model_to_species.to_sql('model_to_species', con=engine, index=False, 
                        chunksize=100, if_exists = 'replace')
# Out:
# 40
# 40
